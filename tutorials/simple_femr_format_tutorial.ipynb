# %% [markdown]
# # Creating a dataset with a simple format
# In this tutorial, we will walk through how to generate a dataset using a simple input format that will work with some parts of the FEMR pipeline.

# %%
import os
import csv

# Create directories to save the dataset and associated files 
TARGET_DIR = "trash/simple_femr"
os.makedirs(TARGET_DIR)

INPUT_DIR = os.path.join(TARGET_DIR, "simple_input")
os.mkdir(INPUT_DIR)

# %% [markdown]
# # 1. Basic input schema
# The input schema is a folder of csv files, where each csv file has <u>at minimum</u> the following columns:
#
# >patient_id, start, code, value
#
# where
#  - `patient_id` is the ID for the patient who has the event. `patient_id` must be a 64 bit unsigned integer
#
#  - `start` is the start timestamp for an event, ideally when the event is initially recorded in the database. `start` must be an ISO 8601 timestamp string
#
#  - `code` is a string identifies what the event is. It must internally consist of a vocabulary signifier and the code itself, split by a "/" character. For example ICD10CM/E11.4
#
#  - `value` is a value associated with the event. It can either be a numeric value, an arbitrary string, or an empty string (indicating no value).
#
# Each row in a file corresponds to an event.
#
#
# All different types of EMR data can be mapped to four core columns:
#
# >Demographics, Diagnosis/Procedures, Labs, Medications
#
# and we will demonstrate how to add each data type to a dataset in a sequence.
#
#
#
# # Exercise 1: Add demographic information
# Now, we create a dataset, "minimum.csv", manually that contains a single patient with three rows.
#
# We use patients' date of birth as the very first visit time in our data format, so the first event is always `Birth`
#
# Rows 2 and 3 include the demographic information, `Gender` and `Race`, respectively, of this patient with corresponding values. Demographics should generally be mapped as demographics codes assigned to the birth date of the patient (with no value assigned). For demographic rows, the vocabulary signifier and the code itself are the same.

# %%
with open(os.path.join(INPUT_DIR, "minimum.csv"), "w") as f:
    f.write("patient_id,start,code,value\n")              
    f.write("3,1990-01-07,Birth/Birth,\n")         # First event is always birth
    f.write("3,1990-01-07,Gender/Gender,Female\n") # demographics 
    f.write("3,1990-01-07,Race/Race,White\n")      # demographics
    
with open(os.path.join(INPUT_DIR, "minimum.csv"), newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(', '.join(row))
# Out:
# patient_id,start,code,value
# 3,1990-01-07,Birth/Birth,
# 3,1990-01-07,Gender/Gender,Female
# 3,1990-01-07,Race/Race,White

# %% [markdown]
# # 2. Expanding your dataset
# You may also add arbitrary columns for any csv file. The additional columns will be added to each event. The columns can vary between csv files.
#
#
# # Exercise 2: Add diagnosis information
# We now add more events/rows that capture patients' diagnosis information, e.g., ICD 9/10 codes
#
# For diagnosis, the `code` column has two parts, the vocabulary signifier (e.g., ICD10CM) and the code itself (e.g., E11.4, E10.1, etc.) The `value` column should be left as empty. Procedures and diagnosis codes should generally be mapped to when the event happened.
#
# Note that different diagnoses may be given at different visits, so the corresponding `start` timestamps may be different.

# %%
with open(os.path.join(INPUT_DIR, "diagnosis.csv"), "w") as f:
    f.write("patient_id,start,code,value\n")              
    f.write("3,1970-01-07,Birth/Birth,\n")         
    f.write("3,1990-01-07,Gender/Gender,Female\n") 
    f.write("3,1990-01-07,Race/Race,White\n")      
    f.write("3,2022-05-03,ICD10CM/E11.4,\n")  # diabetes
    f.write("3,2022-06-05,ICD10CM/E10.1,\n")  # hypertension 
    
with open(os.path.join(INPUT_DIR, "diagnosis.csv"), newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(', '.join(row))
# Out:
# patient_id,start,code,value
# 3,1970-01-07,Birth/Birth,
# 3,1990-01-07,Gender/Gender,Female
# 3,1990-01-07,Race/Race,White
# 3,2022-05-03,ICD10CM/E11.4,
# 3,2022-06-05,ICD10CM/E10.1,

# %% [markdown]
# # Exercise 3: Add lab test information
# We now add more events/rows that capture patients' lab values, e.g., Vitals/Blood Pressure
#
# For vitals, the `code` column has two parts, the vocabulary signifier (e.g., Vitals) and the code itself (e.g., Blood Pressure, HbA1c, etc.) The `value` column should contain corresponding numeric values when possible, but text valued otherwise.
#
# We also recommend adding another column, `units`, to record the units of each test result.
#
# Note that different lab tests may be given at different visits, so the corresponding `start` timestamps may differ.

# %%
with open(os.path.join(INPUT_DIR, "lab_tests.csv"), "w") as f:
    f.write("patient_id,start,code,value,units\n")              
    f.write("3,1970-01-07,Birth/Birth,,\n")         
    f.write("3,1990-01-07,Gender/Gender,Female,\n") 
    f.write("3,1990-01-07,Race/Race,White,\n")      
    f.write("3,2022-05-03,ICD10CM/E11.4,,\n")  
    f.write("3,2022-06-05,ICD10CM/E10.1,,\n") 
    f.write("3,2000-07-09,Vitals/Blood Pressure,160,mmHg\n") 
    f.write("3,2000-08-09,Vitals/HbA1c,7,%\n") 
    
with open(os.path.join(INPUT_DIR, "lab_tests.csv"), newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(', '.join(row))
# Out:
# patient_id,start,code,value,units
# 3,1970-01-07,Birth/Birth,,
# 3,1990-01-07,Gender/Gender,Female,
# 3,1990-01-07,Race/Race,White,
# 3,2022-05-03,ICD10CM/E11.4,,
# 3,2022-06-05,ICD10CM/E10.1,,
# 3,2000-07-09,Vitals/Blood, Pressure,160,mmHg
# 3,2000-08-09,Vitals/HbA1c,7,%

# %% [markdown]
# # Exercise 4: Add medication information
# We now add more events/rows that capture patients' medication intake info., e.g., Drug/Atorvastatin
#
# For medications, the `code` column has two parts, the vocabulary signifier (e.g., Drug) and the code itself (e.g., Atorvastatin, Heparin Lock Flush, Multivitamins, etc.) The `value` column should be empty.
#
# We add another column, `dosage`, to record the dose of the prescribed medication. For medications, the `units` column indicates the unit of the medication dose.
#
# Note that different lab tests may be given at different visits, so the corresponding `start` timestamps may differ.

# %%
with open(os.path.join(INPUT_DIR, "drug.csv"), "w") as f:
    f.write("patient_id,start,code,value,units,dosage\n")              
    f.write("3,1970-01-07,Birth/Birth,,,\n")         
    f.write("3,1990-01-07,Gender/Gender,Female,,\n") 
    f.write("3,1990-01-07,Race/Race,White,,\n")      
    f.write("3,2022-05-03,ICD10CM/E11.4,,,\n")  
    f.write("3,2022-06-05,ICD10CM/E10.1,,,\n") 
    f.write("3,2020-07-09,Vitals/Blood Pressure,160,mmHg,\n") 
    f.write("3,2020-08-09,Vitals/HbA1c,7,,%\n") 
    f.write("3,2022-06-05,Drug/Atorvastatin,,mg,50\n") 
    f.write("3,2022-07-06,Drug/Multivitamins,,ml,5\n")
    
with open(os.path.join(INPUT_DIR, "drug.csv"), newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(', '.join(row))
# Out:
# patient_id,start,code,value,units,dosage
# 3,1970-01-07,Birth/Birth,,,
# 3,1990-01-07,Gender/Gender,Female,,
# 3,1990-01-07,Race/Race,White,,
# 3,2022-05-03,ICD10CM/E11.4,,,
# 3,2022-06-05,ICD10CM/E10.1,,,
# 3,2020-07-09,Vitals/Blood, Pressure,160,mmHg,
# 3,2020-08-09,Vitals/HbA1c,7,,%
# 3,2022-06-05,Drug/Atorvastatin,,mg,50
# 3,2022-07-06,Drug/Multivitamins,,ml,5

# %% [markdown]
# # 3. Additional considerations
# When adding columns, the goal is to add as many columns as needed to maximum the clarity and completeness of the raw/original data.
#
# For simplicity, we only included one patient in the above datasets, but an arbitrary number of patients can be captured in the same file by adding more rows with different `patient_id`.
#
#
# # Exercise 5: Generate synthetic examples
# We now create a dataset with 100 synthetic patients' data

# %%
import random
import datetime
import string

def add_random_patient(patient_id, f):
    epoch = datetime.date(1990, 1, 1)
    birth = epoch + datetime.timedelta(days=random.randint(100, 1000))
    current_date = birth
    
    code_cat = ["Birth","Gender", "Race","ICD10CM","CPT", "Drug", "Vitals"]
    gender_values = ["F","M"]
    race_values = ["White","Non-White"]
    index = random.randint(0,1)
    for code_type in code_cat:
        if code_type == "Birth":
            clarity = "PATIENT"
            visit_id = 1
            value = ''
            dosage = ''
            unit = ''
            f.write(f"{patient_id},{birth.isoformat()},{code_type}/{code_type},{value},{dosage},{visit_id},{unit},{clarity}\n")
        elif code_type == "Gender":
            clarity = "PATIENT"
            visit_id = 1
            value = gender_values[index]
            dosage = ''
            unit = ''
            f.write(f"{patient_id},{birth.isoformat()},{code_type}/{code_type},{value},{dosage},{visit_id},{unit},{clarity}\n")
        elif code_type == "Race":
            clarity = "PATIENT"
            visit_id = 1
            value = race_values[index]
            dosage = ''
            unit = ''
            f.write(f"{patient_id},{birth.isoformat()},{code_type}/{code_type},{value},{dosage},{visit_id},{unit},{clarity}\n") 
        else:
            for code in range(random.randint(1, 10)):
                code = ''.join(random.choices(string.ascii_uppercase + string.digits, k=8))
                current_date = current_date +  datetime.timedelta(days=random.randint(0, 100))
                visit_id = random.randint(0,20)
                if code_type == "ICD10CM":
                    clarity = "DIAGNOSIS"
                    value = ''
                    dosage = ''
                    unit = ''
                elif code_type == "CPT":
                    clarity = "PROCEDURES"
                    value = ''
                    dosage = ''
                    unit = ''
                elif code_type == "Drug":
                    clarity = "MED_ORDER"
                    value = ''
                    dosage = random.randint(10,50)
                    unit = "mg"
                elif code_type == "Vitals":
                    clarity = "LAB_RESULT"
                    value = random.randint(80,200)
                    dosage = ''
                    unit = "mmHg"
                f.write(f"{patient_id},{current_date.isoformat()},{code_type}/{code},{value},{dosage},{visit_id},{unit},{clarity}\n")

# %%
for file_no in range(1, 2):
    with open(os.path.join(INPUT_DIR, f"{file_no}.csv"), "w") as f:    
        # Use the simpler 4 column minimum format, with no optional columns
        f.write("patient_id,start,code,value,dosage,visit_ids,lab_units,clarity_source\n")
        for patient_id in range(file_no * 100, (file_no + 1) * 100):
            add_random_patient(patient_id, f)
        
        with open(os.path.join(INPUT_DIR, f"{file_no}.csv"), newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
            for row in spamreader:
                print(', '.join(row))
# Out:
# patient_id,start,code,value,dosage,visit_ids,lab_units,clarity_source
# 100,1992-08-28,Birth/Birth,,,1,,PATIENT
# 100,1992-08-28,Gender/Gender,F,,1,,PATIENT
# 100,1992-08-28,Race/Race,White,,1,,PATIENT
# 100,1992-11-15,ICD10CM/8RGSN32K,,,13,,DIAGNOSIS
# 100,1993-01-30,ICD10CM/K59YO0LH,,,4,,DIAGNOSIS
# 100,1993-03-20,CPT/CVGA0L2C,,,2,,PROCEDURES
# 100,1993-03-27,CPT/NW9ITAQ3,,,7,,PROCEDURES
# 100,1993-06-18,CPT/L85SUOU2,,,3,,PROCEDURES
# 100,1993-08-31,CPT/7I2C7X33,,,20,,PROCEDURES
# 100,1993-08-31,CPT/BJAGWXD4,,,15,,PROCEDURES
# 100,1993-09-24,Drug/LAC2GO6U,,22,14,mg,MED_ORDER
# 100,1993-10-18,Drug/U6M468D7,,13,7,mg,MED_ORDER
# 100,1993-12-09,Drug/5RI7VTP5,,41,15,mg,MED_ORDER
# 100,1994-02-21,Drug/29FN1ZI0,,15,19,mg,MED_ORDER
# 100,1994-03-24,Drug/OKCY9XAF,,24,0,mg,MED_ORDER
# 100,1994-05-10,Drug/V619Q4IJ,,14,9,mg,MED_ORDER
# 100,1994-07-08,Drug/2V1CAW36,,23,9,mg,MED_ORDER
# 100,1994-08-04,Drug/6DKT18ZI,,44,16,mg,MED_ORDER
# 100,1994-10-14,Drug/5UIC6BEW,,29,9,mg,MED_ORDER
# 100,1994-12-19,Drug/O4ATG34K,,10,10,mg,MED_ORDER
# 100,1995-01-07,Vitals/4CYCUC2T,197,,13,mmHg,LAB_RESULT
# 100,1995-02-13,Vitals/PH8HR0UH,130,,3,mmHg,LAB_RESULT
# 100,1995-05-21,Vitals/DYVZFZ4G,151,,0,mmHg,LAB_RESULT
# 100,1995-05-24,Vitals/POJUXY4H,186,,0,mmHg,LAB_RESULT
# 101,1990-11-04,Birth/Birth,,,1,,PATIENT
# 101,1990-11-04,Gender/Gender,M,,1,,PATIENT
# 101,1990-11-04,Race/Race,Non-White,,1,,PATIENT
# 101,1990-12-26,ICD10CM/S6S4QTY5,,,20,,DIAGNOSIS
# 101,1990-12-31,ICD10CM/VQCFUHGU,,,17,,DIAGNOSIS
# 101,1991-01-31,ICD10CM/MUA4TS6U,,,1,,DIAGNOSIS
# 101,1991-04-22,ICD10CM/S48W80D2,,,13,,DIAGNOSIS
# 101,1991-05-11,ICD10CM/KUR28OLB,,,11,,DIAGNOSIS
# 101,1991-06-30,ICD10CM/T2K4LASZ,,,20,,DIAGNOSIS
# 101,1991-09-30,ICD10CM/04SJOOX5,,,7,,DIAGNOSIS
# 101,1991-12-22,ICD10CM/ZM1NI6HJ,,,5,,DIAGNOSIS
# 101,1992-02-24,ICD10CM/KJIUINHT,,,3,,DIAGNOSIS
# 101,1992-03-19,CPT/QLFKNHWQ,,,16,,PROCEDURES
# 101,1992-06-14,CPT/6SRBHS58,,,3,,PROCEDURES
# 101,1992-07-20,CPT/56H3BFAT,,,18,,PROCEDURES
# 101,1992-10-05,CPT/0O85YBXJ,,,18,,PROCEDURES
# 101,1992-10-13,CPT/S041H67H,,,17,,PROCEDURES
# 101,1992-12-27,CPT/T9STA086,,,10,,PROCEDURES
# 101,1993-01-19,CPT/CQCHN1JY,,,10,,PROCEDURES
# 101,1993-03-01,CPT/OYK69GCR,,,8,,PROCEDURES
# 101,1993-03-18,CPT/90GIB1R7,,,14,,PROCEDURES
# 101,1993-04-07,Drug/6XBFDOU2,,21,6,mg,MED_ORDER
# 101,1993-06-04,Drug/R2699O5I,,41,18,mg,MED_ORDER
# 101,1993-06-28,Vitals/M4MECVFN,168,,20,mmHg,LAB_RESULT
# 101,1993-09-13,Vitals/I0JW8PJ3,98,,18,mmHg,LAB_RESULT
# 101,1993-10-09,Vitals/5M8CY0XW,150,,14,mmHg,LAB_RESULT
# 101,1993-11-25,Vitals/J65IT624,188,,6,mmHg,LAB_RESULT
# 101,1994-02-27,Vitals/TRNTKHGN,171,,6,mmHg,LAB_RESULT
# 101,1994-04-21,Vitals/VJ0MMFAW,141,,2,mmHg,LAB_RESULT
# 101,1994-05-18,Vitals/5I3GQ7CU,188,,1,mmHg,LAB_RESULT
# 101,1994-06-27,Vitals/I2LGBANY,168,,9,mmHg,LAB_RESULT
# 101,1994-06-30,Vitals/WJS1GS1P,142,,19,mmHg,LAB_RESULT
# 102,1991-07-09,Birth/Birth,,,1,,PATIENT
# 102,1991-07-09,Gender/Gender,M,,1,,PATIENT
# 102,1991-07-09,Race/Race,Non-White,,1,,PATIENT
# 102,1991-10-17,ICD10CM/3J09HE1N,,,16,,DIAGNOSIS
# 102,1991-11-21,ICD10CM/SJO6OUEN,,,4,,DIAGNOSIS
# 102,1992-01-21,ICD10CM/O8O8Y197,,,6,,DIAGNOSIS
# 102,1992-01-23,ICD10CM/C8U0BS97,,,10,,DIAGNOSIS
# 102,1992-03-21,ICD10CM/PX2ERT4M,,,3,,DIAGNOSIS
# 102,1992-04-12,ICD10CM/WRLD4ECJ,,,0,,DIAGNOSIS
# 102,1992-06-11,CPT/NY9QSEYM,,,7,,PROCEDURES
# 102,1992-07-18,CPT/IOLJOHBU,,,5,,PROCEDURES
# 102,1992-10-04,CPT/4I2IQFPP,,,15,,PROCEDURES
# 102,1992-10-16,CPT/GT2U5U9Q,,,18,,PROCEDURES
# 102,1992-11-22,CPT/Q4CNE2M4,,,20,,PROCEDURES
# 102,1993-01-11,CPT/1G96RRLP,,,8,,PROCEDURES
# 102,1993-04-13,CPT/A79PKA5M,,,0,,PROCEDURES
# 102,1993-05-04,CPT/33V9J44R,,,12,,PROCEDURES
# 102,1993-07-31,CPT/QJMWHBPC,,,18,,PROCEDURES
# 102,1993-09-11,Drug/KVONPZKX,,35,17,mg,MED_ORDER
# 102,1993-11-05,Drug/YBTIBN0S,,49,4,mg,MED_ORDER
# 102,1994-01-21,Vitals/SOBJFZOC,156,,16,mmHg,LAB_RESULT
# 102,1994-03-15,Vitals/XXMXAHIB,189,,19,mmHg,LAB_RESULT
# 102,1994-06-03,Vitals/VLR2N6CV,164,,16,mmHg,LAB_RESULT
# 102,1994-08-17,Vitals/ECHV4SEY,106,,0,mmHg,LAB_RESULT
# 102,1994-11-15,Vitals/CARVOI8H,106,,19,mmHg,LAB_RESULT
# 102,1995-01-13,Vitals/GQ7HVG2I,113,,3,mmHg,LAB_RESULT
# 102,1995-02-14,Vitals/UQ9A6E46,87,,14,mmHg,LAB_RESULT
# 102,1995-04-27,Vitals/0K9OOD8P,175,,20,mmHg,LAB_RESULT
# 102,1995-07-21,Vitals/DTXWG7GA,88,,16,mmHg,LAB_RESULT
# 103,1992-03-03,Birth/Birth,,,1,,PATIENT
# 103,1992-03-03,Gender/Gender,F,,1,,PATIENT
# 103,1992-03-03,Race/Race,White,,1,,PATIENT
# 103,1992-04-14,ICD10CM/LE8XT5L6,,,7,,DIAGNOSIS
# 103,1992-07-09,ICD10CM/PAAZA4TJ,,,13,,DIAGNOSIS
# 103,1992-08-04,ICD10CM/96C4Y6FM,,,18,,DIAGNOSIS
# 103,1992-08-21,ICD10CM/L64EL89I,,,1,,DIAGNOSIS
# 103,1992-10-12,CPT/RJLQ6C0K,,,5,,PROCEDURES
# 103,1992-12-03,CPT/HLPGF3Z4,,,17,,PROCEDURES
# 103,1993-02-23,Drug/WIBZTHMD,,32,0,mg,MED_ORDER
# 103,1993-04-25,Drug/E4UWW2KM,,10,13,mg,MED_ORDER
# 103,1993-06-07,Drug/VFV7SXTM,,50,19,mg,MED_ORDER
# 103,1993-09-14,Drug/0ARDFX8N,,41,12,mg,MED_ORDER
# 103,1993-11-10,Drug/22D2YBJ6,,39,6,mg,MED_ORDER
# 103,1993-11-26,Drug/GT8LNUFW,,35,8,mg,MED_ORDER
# 103,1993-12-12,Drug/WG29IJXZ,,16,9,mg,MED_ORDER
# 103,1994-02-11,Drug/OWYHE272,,40,6,mg,MED_ORDER
# 103,1994-04-15,Drug/RIEPREA5,,48,6,mg,MED_ORDER
# 103,1994-05-23,Vitals/S7Q3QP0G,200,,15,mmHg,LAB_RESULT
# 103,1994-07-19,Vitals/B21P188L,81,,17,mmHg,LAB_RESULT
# 103,1994-09-08,Vitals/DMEU5FYN,188,,11,mmHg,LAB_RESULT
# 103,1994-11-29,Vitals/MH6KPP1W,179,,19,mmHg,LAB_RESULT
# 104,1991-07-06,Birth/Birth,,,1,,PATIENT
# 104,1991-07-06,Gender/Gender,F,,1,,PATIENT
# 104,1991-07-06,Race/Race,White,,1,,PATIENT
# 104,1991-07-26,ICD10CM/KCANU32L,,,15,,DIAGNOSIS
# 104,1991-09-11,ICD10CM/S7NKOA58,,,17,,DIAGNOSIS
# 104,1991-09-18,ICD10CM/G2VGD8XL,,,19,,DIAGNOSIS
# 104,1991-11-10,ICD10CM/6J87CWND,,,7,,DIAGNOSIS
# 104,1992-02-15,ICD10CM/MCIGTPIJ,,,17,,DIAGNOSIS
# 104,1992-03-24,ICD10CM/8LDDQXGV,,,5,,DIAGNOSIS
# 104,1992-04-03,ICD10CM/7HJQ8V3X,,,9,,DIAGNOSIS
# 104,1992-05-10,ICD10CM/0AF2DOLP,,,6,,DIAGNOSIS
# 104,1992-06-13,ICD10CM/GWPYQBBD,,,17,,DIAGNOSIS
# 104,1992-09-15,CPT/UQ8JL6CF,,,16,,PROCEDURES
# 104,1992-11-13,CPT/YLX51WXN,,,3,,PROCEDURES
# 104,1993-01-23,CPT/J35N41CY,,,6,,PROCEDURES
# 104,1993-04-25,CPT/1ZDSM8XL,,,11,,PROCEDURES
# 104,1993-06-05,CPT/AO98K6T6,,,17,,PROCEDURES
# 104,1993-06-17,CPT/MUYT8W5F,,,15,,PROCEDURES
# 104,1993-09-13,CPT/HZN25EFP,,,4,,PROCEDURES
# 104,1993-11-25,Drug/0HL06XE4,,19,2,mg,MED_ORDER
# 104,1994-01-02,Drug/UCYYLRA2,,26,9,mg,MED_ORDER
# 104,1994-01-03,Drug/72LZBW98,,18,16,mg,MED_ORDER
# 104,1994-03-13,Drug/BE2YVTV7,,19,10,mg,MED_ORDER
# 104,1994-03-22,Drug/4L3T8GB4,,21,1,mg,MED_ORDER
# 104,1994-04-05,Drug/CRMN2C0L,,46,0,mg,MED_ORDER
# 104,1994-06-16,Drug/YLCRJL8L,,17,18,mg,MED_ORDER
# 104,1994-06-23,Drug/DM33VI6C,,42,16,mg,MED_ORDER
# 104,1994-07-01,Drug/FMUK9NLY,,40,10,mg,MED_ORDER
# 104,1994-08-03,Drug/GV51O7GQ,,33,17,mg,MED_ORDER
# 104,1994-10-28,Vitals/P2YEUMPB,166,,9,mmHg,LAB_RESULT
# 104,1994-11-28,Vitals/QROJWKDQ,96,,1,mmHg,LAB_RESULT
# 104,1995-03-06,Vitals/I3MMCFGB,113,,2,mmHg,LAB_RESULT
# 104,1995-06-14,Vitals/1X93D6HH,186,,9,mmHg,LAB_RESULT
# 105,1992-03-22,Birth/Birth,,,1,,PATIENT
# 105,1992-03-22,Gender/Gender,F,,1,,PATIENT
# 105,1992-03-22,Race/Race,White,,1,,PATIENT
# 105,1992-04-22,ICD10CM/WCI91JMW,,,6,,DIAGNOSIS
# 105,1992-06-06,ICD10CM/BB8DP9CE,,,14,,DIAGNOSIS
# 105,1992-08-17,ICD10CM/JS3W6A42,,,9,,DIAGNOSIS
# 105,1992-10-14,ICD10CM/X66T0PJF,,,20,,DIAGNOSIS
# 105,1992-11-17,ICD10CM/SUC7IXOZ,,,13,,DIAGNOSIS
# 105,1993-01-16,ICD10CM/UPIGJA9Y,,,4,,DIAGNOSIS
# 105,1993-04-02,CPT/H1IV0W7U,,,10,,PROCEDURES
# 105,1993-05-01,CPT/KM7AZB96,,,2,,PROCEDURES
# 105,1993-05-27,CPT/DZUW6XCI,,,18,,PROCEDURES
# 105,1993-08-19,CPT/832CU63V,,,18,,PROCEDURES
# 105,1993-11-27,CPT/6YUV4I2G,,,9,,PROCEDURES
# 105,1993-11-28,CPT/R1B3AX8I,,,0,,PROCEDURES
# 105,1994-01-03,CPT/JNMKI684,,,14,,PROCEDURES
# 105,1994-03-01,CPT/18HV0VJ9,,,19,,PROCEDURES
# 105,1994-03-29,CPT/5OP6VZAK,,,0,,PROCEDURES
# 105,1994-06-05,CPT/IK5ZBLF7,,,11,,PROCEDURES
# 105,1994-09-06,Drug/KSFQHJME,,33,2,mg,MED_ORDER
# 105,1994-12-04,Drug/L9OF0TS4,,44,14,mg,MED_ORDER
# 105,1995-02-27,Vitals/NLV1I13O,168,,3,mmHg,LAB_RESULT
# 106,1991-01-08,Birth/Birth,,,1,,PATIENT
# 106,1991-01-08,Gender/Gender,F,,1,,PATIENT
# 106,1991-01-08,Race/Race,White,,1,,PATIENT
# 106,1991-01-09,ICD10CM/82TOXEWB,,,10,,DIAGNOSIS
# 106,1991-03-24,ICD10CM/USTATJIZ,,,2,,DIAGNOSIS
# 106,1991-04-16,ICD10CM/NLIFI8GO,,,7,,DIAGNOSIS
# 106,1991-05-27,ICD10CM/H4DD3BB2,,,14,,DIAGNOSIS
# 106,1991-07-26,ICD10CM/QWTRX2AO,,,18,,DIAGNOSIS
# 106,1991-10-22,ICD10CM/1JLA31Q9,,,20,,DIAGNOSIS
# 106,1991-10-27,CPT/C9YTKYXK,,,14,,PROCEDURES
# 106,1991-11-25,CPT/MC34TZGE,,,12,,PROCEDURES
# 106,1992-01-31,CPT/NNLKY4T8,,,2,,PROCEDURES
# 106,1992-02-22,CPT/IFC1K5NU,,,3,,PROCEDURES
# 106,1992-04-24,CPT/KNU4RE6D,,,7,,PROCEDURES
# 106,1992-07-20,CPT/XIAZ1CPH,,,1,,PROCEDURES
# 106,1992-07-27,CPT/LCXYKRGK,,,20,,PROCEDURES
# 106,1992-09-24,CPT/OQ5CFVEU,,,19,,PROCEDURES
# 106,1992-12-17,CPT/38O1WTPJ,,,17,,PROCEDURES
# 106,1993-02-20,CPT/TVVT90C2,,,1,,PROCEDURES
# 106,1993-02-28,Drug/FEJDTQ96,,32,10,mg,MED_ORDER
# 106,1993-03-16,Drug/TPN4M7W7,,20,5,mg,MED_ORDER
# 106,1993-05-09,Drug/3D3R39DR,,28,15,mg,MED_ORDER
# 106,1993-06-15,Drug/ZYBM0MGQ,,25,19,mg,MED_ORDER
# 106,1993-09-16,Vitals/6OA6IIOB,196,,4,mmHg,LAB_RESULT
# 107,1991-01-11,Birth/Birth,,,1,,PATIENT
# 107,1991-01-11,Gender/Gender,F,,1,,PATIENT
# 107,1991-01-11,Race/Race,White,,1,,PATIENT
# 107,1991-03-23,ICD10CM/ES7DRAUI,,,13,,DIAGNOSIS
# 107,1991-06-23,ICD10CM/FJA04B9K,,,12,,DIAGNOSIS
# 107,1991-07-01,ICD10CM/MTSRNQ13,,,13,,DIAGNOSIS
# 107,1991-07-09,ICD10CM/XTHB7CEI,,,16,,DIAGNOSIS
# 107,1991-10-17,ICD10CM/JHDZ3THN,,,18,,DIAGNOSIS
# 107,1991-11-21,ICD10CM/V03OG1UC,,,16,,DIAGNOSIS
# 107,1992-01-04,ICD10CM/M9LYB76H,,,6,,DIAGNOSIS
# 107,1992-01-12,ICD10CM/K3F3O033,,,18,,DIAGNOSIS
# 107,1992-02-18,CPT/ZJ47MNA0,,,0,,PROCEDURES
# 107,1992-04-08,CPT/WHQXOWN1,,,11,,PROCEDURES
# 107,1992-06-20,CPT/O2TW5VVN,,,3,,PROCEDURES
# 107,1992-06-25,CPT/0ZJTHNA5,,,4,,PROCEDURES
# 107,1992-07-10,CPT/8HIWPKHS,,,9,,PROCEDURES
# 107,1992-08-31,CPT/39YDUL41,,,2,,PROCEDURES
# 107,1992-11-05,CPT/OZAOYQ92,,,14,,PROCEDURES
# 107,1992-11-12,CPT/E2TD0X5L,,,5,,PROCEDURES
# 107,1992-12-15,CPT/NLFNLQNJ,,,11,,PROCEDURES
# 107,1993-01-14,CPT/UYORRSHC,,,10,,PROCEDURES
# 107,1993-01-28,Drug/T20S8MUW,,41,12,mg,MED_ORDER
# 107,1993-03-12,Drug/6O8VSDXZ,,37,1,mg,MED_ORDER
# 107,1993-05-08,Drug/VJTIZXNH,,22,10,mg,MED_ORDER
# 107,1993-06-11,Drug/GGZN9MI4,,36,7,mg,MED_ORDER
# 107,1993-07-09,Drug/8TOBL21K,,36,8,mg,MED_ORDER
# 107,1993-08-03,Drug/RH93O5OL,,30,1,mg,MED_ORDER
# 107,1993-10-25,Drug/U4CN0KER,,41,14,mg,MED_ORDER
# 107,1993-11-13,Drug/KG6IGIC7,,46,17,mg,MED_ORDER
# 107,1994-02-04,Vitals/GITAOOLI,151,,8,mmHg,LAB_RESULT
# 107,1994-02-27,Vitals/TAKOKE1G,103,,3,mmHg,LAB_RESULT
# 107,1994-03-26,Vitals/XFT4WHHU,198,,9,mmHg,LAB_RESULT
# 107,1994-05-15,Vitals/3T7CXULM,93,,20,mmHg,LAB_RESULT
# 107,1994-05-22,Vitals/1HMTFS91,143,,6,mmHg,LAB_RESULT
# 107,1994-08-02,Vitals/A5K87BX9,187,,6,mmHg,LAB_RESULT
# 107,1994-10-27,Vitals/NUGD0S13,133,,10,mmHg,LAB_RESULT
# 107,1994-11-27,Vitals/5JAR0ZDJ,151,,16,mmHg,LAB_RESULT
# 107,1994-12-30,Vitals/LCYZU0XA,168,,5,mmHg,LAB_RESULT
# 107,1995-01-27,Vitals/I05GARMO,134,,19,mmHg,LAB_RESULT
# 108,1991-03-21,Birth/Birth,,,1,,PATIENT
# 108,1991-03-21,Gender/Gender,M,,1,,PATIENT
# 108,1991-03-21,Race/Race,Non-White,,1,,PATIENT
# 108,1991-05-22,ICD10CM/1VNB7QX3,,,4,,DIAGNOSIS
# 108,1991-05-23,ICD10CM/Z40UWNLQ,,,6,,DIAGNOSIS
# 108,1991-08-13,CPT/NDFIZRJ5,,,7,,PROCEDURES
# 108,1991-10-30,CPT/SBWHCE41,,,4,,PROCEDURES
# 108,1992-01-01,Drug/2M4PKHVM,,29,14,mg,MED_ORDER
# 108,1992-04-10,Drug/LEHDZ5LT,,42,4,mg,MED_ORDER
# 108,1992-06-10,Vitals/NC7RPNY2,142,,7,mmHg,LAB_RESULT
# 108,1992-07-18,Vitals/TBZ364WH,114,,20,mmHg,LAB_RESULT
# 108,1992-08-10,Vitals/H1UJVQEA,145,,11,mmHg,LAB_RESULT
# 108,1992-11-14,Vitals/PH0TVBOC,153,,20,mmHg,LAB_RESULT
# 108,1993-01-05,Vitals/Z8VW7UQ0,179,,1,mmHg,LAB_RESULT
# 108,1993-03-15,Vitals/JYUJSBO5,99,,13,mmHg,LAB_RESULT
# 108,1993-06-08,Vitals/G61M3V6J,122,,15,mmHg,LAB_RESULT
# 109,1991-10-07,Birth/Birth,,,1,,PATIENT
# 109,1991-10-07,Gender/Gender,M,,1,,PATIENT
# 109,1991-10-07,Race/Race,Non-White,,1,,PATIENT
# 109,1991-12-13,ICD10CM/BFBH85JT,,,8,,DIAGNOSIS
# 109,1992-03-18,CPT/6M45PX0B,,,6,,PROCEDURES
# 109,1992-03-30,CPT/IGJNBHVP,,,13,,PROCEDURES
# 109,1992-04-27,CPT/4I35V287,,,17,,PROCEDURES
# 109,1992-08-01,CPT/E4E2IG9D,,,13,,PROCEDURES
# 109,1992-09-06,Drug/GZ4I6ZUA,,37,20,mg,MED_ORDER
# 109,1992-09-18,Drug/1702K0H8,,31,4,mg,MED_ORDER
# 109,1992-11-19,Drug/NC4GQ7QD,,50,0,mg,MED_ORDER
# 109,1993-01-29,Drug/U40Y5Y0V,,42,0,mg,MED_ORDER
# 109,1993-02-28,Drug/WKUXRPIP,,23,14,mg,MED_ORDER
# 109,1993-06-07,Drug/F3RPI71G,,44,7,mg,MED_ORDER
# 109,1993-06-11,Drug/5714T8U2,,29,10,mg,MED_ORDER
# 109,1993-08-30,Drug/LNRQWLY1,,41,6,mg,MED_ORDER
# 109,1993-11-17,Drug/GF7SNJKG,,50,7,mg,MED_ORDER
# 109,1994-01-21,Drug/INFMMW80,,36,1,mg,MED_ORDER
# 109,1994-03-04,Vitals/VW4LF83Q,86,,14,mmHg,LAB_RESULT
# 109,1994-06-04,Vitals/GW16EHFE,127,,12,mmHg,LAB_RESULT
# 109,1994-06-04,Vitals/O2TS5IS0,193,,10,mmHg,LAB_RESULT
# 110,1992-01-03,Birth/Birth,,,1,,PATIENT
# 110,1992-01-03,Gender/Gender,F,,1,,PATIENT
# 110,1992-01-03,Race/Race,White,,1,,PATIENT
# 110,1992-03-18,ICD10CM/ZAIHDVGX,,,3,,DIAGNOSIS
# 110,1992-04-12,ICD10CM/4VASYFGP,,,18,,DIAGNOSIS
# 110,1992-04-15,ICD10CM/4X627DQ4,,,6,,DIAGNOSIS
# 110,1992-07-01,ICD10CM/QDE2BHNL,,,2,,DIAGNOSIS
# 110,1992-09-03,ICD10CM/PNE3FH11,,,12,,DIAGNOSIS
# 110,1992-11-03,ICD10CM/MS42U1SA,,,6,,DIAGNOSIS
# 110,1992-12-07,ICD10CM/F3ZDSBTD,,,8,,DIAGNOSIS
# 110,1993-02-20,CPT/V9MZFNYV,,,17,,PROCEDURES
# 110,1993-04-08,CPT/7LQ2WGSX,,,17,,PROCEDURES
# 110,1993-07-04,CPT/0LQ1UWT2,,,4,,PROCEDURES
# 110,1993-09-07,CPT/8YSAVXOJ,,,5,,PROCEDURES
# 110,1993-11-30,Drug/5Y15K1P7,,19,19,mg,MED_ORDER
# 110,1994-01-05,Drug/YL3X2BRK,,48,18,mg,MED_ORDER
# 110,1994-01-11,Drug/V4X0SJCU,,30,2,mg,MED_ORDER
# 110,1994-03-08,Drug/WAM4ZT2Z,,20,7,mg,MED_ORDER
# 110,1994-05-12,Drug/9G11FKFB,,12,17,mg,MED_ORDER
# 110,1994-07-20,Drug/DJEEV0TU,,15,6,mg,MED_ORDER
# 110,1994-10-07,Drug/4FMP0UYC,,15,12,mg,MED_ORDER
# 110,1994-10-19,Drug/DZCESAN8,,21,3,mg,MED_ORDER
# 110,1994-11-14,Vitals/4BE0ROS4,108,,13,mmHg,LAB_RESULT
# 110,1994-11-15,Vitals/MR2MPI10,131,,19,mmHg,LAB_RESULT
# 110,1995-02-02,Vitals/IVEB3DD4,130,,5,mmHg,LAB_RESULT
# 110,1995-02-28,Vitals/HOHLFXXN,185,,4,mmHg,LAB_RESULT
# 110,1995-05-23,Vitals/SJOPDK2N,111,,3,mmHg,LAB_RESULT
# 110,1995-06-11,Vitals/WI4L93CX,198,,19,mmHg,LAB_RESULT
# 110,1995-07-30,Vitals/QV8SGQ6Q,102,,12,mmHg,LAB_RESULT
# 110,1995-10-19,Vitals/L9RLZUOU,151,,13,mmHg,LAB_RESULT
# 111,1990-09-12,Birth/Birth,,,1,,PATIENT
# 111,1990-09-12,Gender/Gender,M,,1,,PATIENT
# 111,1990-09-12,Race/Race,Non-White,,1,,PATIENT
# 111,1990-09-12,ICD10CM/5489QFXK,,,14,,DIAGNOSIS
# 111,1990-10-06,ICD10CM/5D1KKA7F,,,9,,DIAGNOSIS
# 111,1990-10-08,ICD10CM/OQ4N9HUE,,,14,,DIAGNOSIS
# 111,1990-12-02,ICD10CM/RMQ5MSK4,,,17,,DIAGNOSIS
# 111,1991-01-29,CPT/PLQIPM8K,,,6,,PROCEDURES
# 111,1991-04-18,Drug/VB45V0X8,,49,7,mg,MED_ORDER
# 111,1991-06-06,Drug/CQXMME5N,,22,18,mg,MED_ORDER
# 111,1991-07-18,Drug/ZQDREVNF,,39,19,mg,MED_ORDER
# 111,1991-07-18,Drug/UURA3HN7,,11,20,mg,MED_ORDER
# 111,1991-10-23,Drug/W0RC18Y5,,29,12,mg,MED_ORDER
# 111,1991-10-26,Drug/SPRCWM1A,,41,18,mg,MED_ORDER
# 111,1991-12-24,Drug/BOB1NXA3,,21,2,mg,MED_ORDER
# 111,1992-02-28,Drug/2UJ22YYO,,32,12,mg,MED_ORDER
# 111,1992-05-27,Drug/OY5I3UF6,,26,17,mg,MED_ORDER
# 111,1992-07-09,Drug/E09WPG1I,,50,16,mg,MED_ORDER
# 111,1992-09-20,Vitals/QYIVGH5V,165,,9,mmHg,LAB_RESULT
# 111,1992-09-28,Vitals/7GT7METD,183,,14,mmHg,LAB_RESULT
# 111,1992-10-31,Vitals/XZUBZF11,133,,3,mmHg,LAB_RESULT
# 111,1993-01-15,Vitals/NOITYH7F,170,,7,mmHg,LAB_RESULT
# 111,1993-02-25,Vitals/ZAOFPJZW,164,,1,mmHg,LAB_RESULT
# 111,1993-05-17,Vitals/U9ULU9CG,176,,7,mmHg,LAB_RESULT
# 111,1993-07-17,Vitals/XUA0TBTZ,161,,11,mmHg,LAB_RESULT
# 111,1993-08-07,Vitals/XUBYIZVQ,163,,15,mmHg,LAB_RESULT
# 111,1993-11-09,Vitals/CIKKWSDX,145,,15,mmHg,LAB_RESULT
# 112,1992-05-04,Birth/Birth,,,1,,PATIENT
# 112,1992-05-04,Gender/Gender,M,,1,,PATIENT
# 112,1992-05-04,Race/Race,Non-White,,1,,PATIENT
# 112,1992-08-11,ICD10CM/XDB42V81,,,4,,DIAGNOSIS
# 112,1992-08-28,ICD10CM/QURI33AG,,,13,,DIAGNOSIS
# 112,1992-10-31,ICD10CM/ILTGU0GO,,,1,,DIAGNOSIS
# 112,1992-10-31,ICD10CM/5YBRZOE1,,,10,,DIAGNOSIS
# 112,1993-02-01,ICD10CM/UPV7FWBN,,,5,,DIAGNOSIS
# 112,1993-04-28,ICD10CM/6SXAF0F7,,,6,,DIAGNOSIS
# 112,1993-07-23,ICD10CM/GRCNSN3P,,,8,,DIAGNOSIS
# 112,1993-07-24,ICD10CM/DM0SR7MK,,,19,,DIAGNOSIS
# 112,1993-09-09,CPT/K0J7JP50,,,3,,PROCEDURES
# 112,1993-09-29,CPT/GZRTY7CV,,,13,,PROCEDURES
# 112,1993-12-09,CPT/03OYNFSS,,,17,,PROCEDURES
# 112,1994-03-07,CPT/BH05YT79,,,15,,PROCEDURES
# 112,1994-04-27,CPT/8TFQRVEK,,,16,,PROCEDURES
# 112,1994-05-25,CPT/7LXQ5QQ1,,,15,,PROCEDURES
# 112,1994-08-10,Drug/P3WS5BRX,,45,1,mg,MED_ORDER
# 112,1994-10-22,Drug/ZW8NJP6X,,13,13,mg,MED_ORDER
# 112,1995-01-28,Drug/12HA2PYK,,24,18,mg,MED_ORDER
# 112,1995-04-12,Drug/MSSI42I7,,42,0,mg,MED_ORDER
# 112,1995-04-14,Drug/HLLSHJC0,,41,17,mg,MED_ORDER
# 112,1995-05-21,Drug/XYPK2DWT,,25,6,mg,MED_ORDER
# 112,1995-08-27,Drug/J6BJIM0C,,11,8,mg,MED_ORDER
# 112,1995-10-22,Drug/7ZWZ80Q7,,43,16,mg,MED_ORDER
# 112,1995-12-21,Drug/Y2Y03COL,,48,20,mg,MED_ORDER
# 112,1996-01-26,Vitals/0VC3J0CX,81,,11,mmHg,LAB_RESULT
# 112,1996-03-25,Vitals/KEX5NK6B,97,,6,mmHg,LAB_RESULT
# 112,1996-04-01,Vitals/APOEU4T3,180,,16,mmHg,LAB_RESULT
# 112,1996-04-11,Vitals/G832I73P,192,,3,mmHg,LAB_RESULT
# 112,1996-06-22,Vitals/RFKAK7VL,184,,19,mmHg,LAB_RESULT
# 113,1990-07-31,Birth/Birth,,,1,,PATIENT
# 113,1990-07-31,Gender/Gender,F,,1,,PATIENT
# 113,1990-07-31,Race/Race,White,,1,,PATIENT
# 113,1990-09-19,ICD10CM/P73UUU3N,,,11,,DIAGNOSIS
# 113,1990-10-31,CPT/Y3F9CP3A,,,2,,PROCEDURES
# 113,1991-02-03,CPT/MQNKL6H4,,,5,,PROCEDURES
# 113,1991-04-14,CPT/7DFAUYFY,,,10,,PROCEDURES
# 113,1991-05-19,CPT/TDTVHONL,,,5,,PROCEDURES
# 113,1991-05-23,Drug/KPOJFN19,,49,10,mg,MED_ORDER
# 113,1991-06-19,Drug/AYTJMPHH,,34,3,mg,MED_ORDER
# 113,1991-08-18,Drug/58R6CPL6,,44,8,mg,MED_ORDER
# 113,1991-10-02,Drug/SL0R8C09,,18,1,mg,MED_ORDER
# 113,1991-11-12,Drug/7B53LQRU,,30,10,mg,MED_ORDER
# 113,1991-12-09,Drug/15EG8BER,,33,10,mg,MED_ORDER
# 113,1992-02-18,Vitals/QE60BF1I,110,,7,mmHg,LAB_RESULT
# 113,1992-05-13,Vitals/L8YD6HBD,119,,12,mmHg,LAB_RESULT
# 113,1992-07-27,Vitals/ILBVUP2L,189,,2,mmHg,LAB_RESULT
# 113,1992-10-11,Vitals/D37ATJ90,152,,20,mmHg,LAB_RESULT
# 113,1992-12-15,Vitals/QFC8Q5L6,163,,0,mmHg,LAB_RESULT
# 113,1993-03-07,Vitals/0QNM0GD1,155,,6,mmHg,LAB_RESULT
# 113,1993-05-22,Vitals/4Z14FMIW,184,,1,mmHg,LAB_RESULT
# 113,1993-06-08,Vitals/SHUVSI20,80,,5,mmHg,LAB_RESULT
# 113,1993-06-30,Vitals/0WR82FFA,116,,8,mmHg,LAB_RESULT
# 113,1993-09-03,Vitals/EJIYY6J9,114,,14,mmHg,LAB_RESULT
# 114,1992-02-04,Birth/Birth,,,1,,PATIENT
# 114,1992-02-04,Gender/Gender,F,,1,,PATIENT
# 114,1992-02-04,Race/Race,White,,1,,PATIENT
# 114,1992-02-27,ICD10CM/N280DF2W,,,11,,DIAGNOSIS
# 114,1992-04-26,ICD10CM/KW2RD6IE,,,17,,DIAGNOSIS
# 114,1992-05-10,ICD10CM/NQHHY6V8,,,16,,DIAGNOSIS
# 114,1992-07-23,ICD10CM/BB6KR6B9,,,12,,DIAGNOSIS
# 114,1992-10-16,ICD10CM/LCKN6BKJ,,,13,,DIAGNOSIS
# 114,1992-12-24,CPT/X5PNFVFL,,,3,,PROCEDURES
# 114,1993-03-06,CPT/3TSNI71A,,,14,,PROCEDURES
# 114,1993-04-06,CPT/KQGL6LUF,,,2,,PROCEDURES
# 114,1993-05-19,CPT/8W62YO2P,,,20,,PROCEDURES
# 114,1993-08-05,CPT/ROI3JB0L,,,20,,PROCEDURES
# 114,1993-08-16,CPT/VCBXPOHF,,,17,,PROCEDURES
# 114,1993-09-20,Drug/DVZDELIL,,35,4,mg,MED_ORDER
# 114,1993-10-11,Drug/REFPYDWP,,17,12,mg,MED_ORDER
# 114,1993-12-19,Drug/PTW0E6UQ,,16,2,mg,MED_ORDER
# 114,1994-02-07,Drug/55Y3N3AC,,38,7,mg,MED_ORDER
# 114,1994-02-22,Vitals/QSEQX6NI,134,,3,mmHg,LAB_RESULT
# 114,1994-03-11,Vitals/0RGODM15,171,,3,mmHg,LAB_RESULT
# 114,1994-03-23,Vitals/TW3CAOUU,84,,0,mmHg,LAB_RESULT
# 114,1994-06-18,Vitals/BBUUOZHI,190,,13,mmHg,LAB_RESULT
# 114,1994-09-19,Vitals/4TMPO1ZI,109,,0,mmHg,LAB_RESULT
# 115,1991-01-11,Birth/Birth,,,1,,PATIENT
# 115,1991-01-11,Gender/Gender,M,,1,,PATIENT
# 115,1991-01-11,Race/Race,Non-White,,1,,PATIENT
# 115,1991-04-08,ICD10CM/0BKI1DN9,,,1,,DIAGNOSIS
# 115,1991-05-27,ICD10CM/MFGPAQ4N,,,15,,DIAGNOSIS
# 115,1991-07-25,ICD10CM/2BML2187,,,16,,DIAGNOSIS
# 115,1991-09-26,CPT/5QR1GIYR,,,6,,PROCEDURES
# 115,1991-12-15,CPT/BACRLN2Y,,,8,,PROCEDURES
# 115,1992-01-21,CPT/QINJ0YCF,,,0,,PROCEDURES
# 115,1992-04-26,CPT/KL7VUAEG,,,20,,PROCEDURES
# 115,1992-07-07,Drug/X4Y8JMTM,,17,12,mg,MED_ORDER
# 115,1992-09-25,Drug/AX90A1LJ,,48,8,mg,MED_ORDER
# 115,1992-11-10,Drug/DKRPPRIC,,32,19,mg,MED_ORDER
# 115,1993-01-16,Drug/63UPO5J9,,44,15,mg,MED_ORDER
# 115,1993-02-20,Drug/SQB9S962,,15,3,mg,MED_ORDER
# 115,1993-04-22,Drug/73HN17UT,,45,9,mg,MED_ORDER
# 115,1993-06-25,Drug/PPFS8M89,,49,12,mg,MED_ORDER
# 115,1993-07-01,Vitals/IZDSG5QG,112,,11,mmHg,LAB_RESULT
# 115,1993-08-18,Vitals/NIUWS57Z,127,,15,mmHg,LAB_RESULT
# 115,1993-10-16,Vitals/HF83KUF2,189,,10,mmHg,LAB_RESULT
# 115,1993-11-25,Vitals/M40MP6KW,113,,0,mmHg,LAB_RESULT
# 115,1993-12-21,Vitals/LTL7YX8W,169,,4,mmHg,LAB_RESULT
# 115,1994-02-18,Vitals/SUV672VP,200,,4,mmHg,LAB_RESULT
# 115,1994-04-24,Vitals/4SHW77HT,193,,5,mmHg,LAB_RESULT
# 116,1992-04-07,Birth/Birth,,,1,,PATIENT
# 116,1992-04-07,Gender/Gender,M,,1,,PATIENT
# 116,1992-04-07,Race/Race,Non-White,,1,,PATIENT
# 116,1992-06-26,ICD10CM/85CIW08Y,,,9,,DIAGNOSIS
# 116,1992-08-30,ICD10CM/M6XBTXN7,,,17,,DIAGNOSIS
# 116,1992-09-01,ICD10CM/RN4M708O,,,8,,DIAGNOSIS
# 116,1992-11-15,ICD10CM/XFWHQY7N,,,15,,DIAGNOSIS
# 116,1993-01-04,ICD10CM/DEI26SVN,,,9,,DIAGNOSIS
# 116,1993-02-15,ICD10CM/YGV9YOS1,,,10,,DIAGNOSIS
# 116,1993-04-28,ICD10CM/DI05PAC0,,,10,,DIAGNOSIS
# 116,1993-06-12,ICD10CM/AS3IMJ3M,,,3,,DIAGNOSIS
# 116,1993-09-05,ICD10CM/I5VIIARQ,,,17,,DIAGNOSIS
# 116,1993-10-15,ICD10CM/PUON6ZPK,,,0,,DIAGNOSIS
# 116,1993-10-16,CPT/F50RJXSG,,,13,,PROCEDURES
# 116,1993-12-07,CPT/RI7D13SE,,,4,,PROCEDURES
# 116,1994-01-25,CPT/78D6RMGC,,,10,,PROCEDURES
# 116,1994-01-30,CPT/VCY1UAC2,,,4,,PROCEDURES
# 116,1994-02-03,CPT/XO53TAPY,,,10,,PROCEDURES
# 116,1994-03-25,CPT/UWHI6GW4,,,13,,PROCEDURES
# 116,1994-05-12,Drug/C9FL59TO,,20,18,mg,MED_ORDER
# 116,1994-06-19,Drug/AGJWHDLI,,50,10,mg,MED_ORDER
# 116,1994-09-06,Drug/UI6V5XVJ,,45,3,mg,MED_ORDER
# 116,1994-12-12,Drug/EF289QE3,,27,5,mg,MED_ORDER
# 116,1995-01-11,Drug/RK1UTRVZ,,23,18,mg,MED_ORDER
# 116,1995-02-22,Drug/NTQ136P6,,12,17,mg,MED_ORDER
# 116,1995-03-07,Drug/82M87EFF,,22,5,mg,MED_ORDER
# 116,1995-06-11,Drug/LCA13Q1F,,30,5,mg,MED_ORDER
# 116,1995-08-24,Drug/HXJCI684,,44,10,mg,MED_ORDER
# 116,1995-08-28,Drug/VTE874SR,,17,4,mg,MED_ORDER
# 116,1995-10-20,Vitals/T1KC9YSF,138,,8,mmHg,LAB_RESULT
# 116,1995-10-24,Vitals/4KNH4KTR,167,,17,mmHg,LAB_RESULT
# 117,1990-07-07,Birth/Birth,,,1,,PATIENT
# 117,1990-07-07,Gender/Gender,F,,1,,PATIENT
# 117,1990-07-07,Race/Race,White,,1,,PATIENT
# 117,1990-09-21,ICD10CM/DK8CANCY,,,1,,DIAGNOSIS
# 117,1990-10-22,ICD10CM/P63KDRMC,,,3,,DIAGNOSIS
# 117,1991-01-29,ICD10CM/416A6UMF,,,6,,DIAGNOSIS
# 117,1991-04-03,CPT/PSHPCNO3,,,15,,PROCEDURES
# 117,1991-04-08,CPT/QLDLDZHI,,,4,,PROCEDURES
# 117,1991-05-14,CPT/7PIWW1RN,,,12,,PROCEDURES
# 117,1991-08-15,CPT/GQVIR3X5,,,1,,PROCEDURES
# 117,1991-10-07,CPT/I1VP5LQ9,,,2,,PROCEDURES
# 117,1991-12-16,Drug/911CM9T4,,43,12,mg,MED_ORDER
# 117,1992-03-25,Drug/AGYHCQ44,,15,14,mg,MED_ORDER
# 117,1992-05-17,Vitals/82T7TXOG,153,,3,mmHg,LAB_RESULT
# 117,1992-07-24,Vitals/2P2A4ZKT,80,,15,mmHg,LAB_RESULT
# 117,1992-10-07,Vitals/2P18RHI9,103,,13,mmHg,LAB_RESULT
# 118,1992-07-02,Birth/Birth,,,1,,PATIENT
# 118,1992-07-02,Gender/Gender,F,,1,,PATIENT
# 118,1992-07-02,Race/Race,White,,1,,PATIENT
# 118,1992-09-21,ICD10CM/I8WWHUSC,,,12,,DIAGNOSIS
# 118,1992-11-22,ICD10CM/6IPFC7UA,,,4,,DIAGNOSIS
# 118,1992-12-11,ICD10CM/LRESLHK8,,,17,,DIAGNOSIS
# 118,1993-03-09,ICD10CM/CA7WNH3A,,,16,,DIAGNOSIS
# 118,1993-04-15,ICD10CM/5PHBYVUF,,,10,,DIAGNOSIS
# 118,1993-07-17,ICD10CM/CO413FY7,,,1,,DIAGNOSIS
# 118,1993-09-05,ICD10CM/ILOXZC90,,,3,,DIAGNOSIS
# 118,1993-10-14,CPT/S14S6KQX,,,14,,PROCEDURES
# 118,1993-12-30,CPT/8XBEN7Q6,,,4,,PROCEDURES
# 118,1994-02-07,CPT/BZDV57NM,,,13,,PROCEDURES
# 118,1994-03-05,CPT/960I5UA3,,,10,,PROCEDURES
# 118,1994-03-05,CPT/VMYEWL11,,,18,,PROCEDURES
# 118,1994-04-16,CPT/ECLNK44V,,,3,,PROCEDURES
# 118,1994-06-14,CPT/N3MRXFH7,,,20,,PROCEDURES
# 118,1994-09-15,Drug/3IT6I9ZH,,39,0,mg,MED_ORDER
# 118,1994-10-23,Drug/NX0AK4TQ,,14,18,mg,MED_ORDER
# 118,1994-11-03,Drug/6ALBLT2Z,,14,11,mg,MED_ORDER
# 118,1995-02-10,Drug/PM543SA0,,31,13,mg,MED_ORDER
# 118,1995-04-03,Drug/824EZKXA,,17,5,mg,MED_ORDER
# 118,1995-06-24,Drug/Q3P33EH9,,13,14,mg,MED_ORDER
# 118,1995-09-19,Drug/2REGY5JO,,30,17,mg,MED_ORDER
# 118,1995-11-28,Drug/FF2U4CWU,,44,11,mg,MED_ORDER
# 118,1996-02-03,Drug/XJLO7UUC,,26,11,mg,MED_ORDER
# 118,1996-05-07,Drug/237RU6M9,,10,7,mg,MED_ORDER
# 118,1996-07-04,Vitals/5HYCME29,100,,13,mmHg,LAB_RESULT
# 118,1996-09-25,Vitals/VHVU3NJC,177,,5,mmHg,LAB_RESULT
# 118,1996-10-29,Vitals/2CHYGGSZ,126,,1,mmHg,LAB_RESULT
# 118,1997-02-01,Vitals/P9UNPO2F,85,,18,mmHg,LAB_RESULT
# 118,1997-03-16,Vitals/627ZZACO,175,,18,mmHg,LAB_RESULT
# 118,1997-04-20,Vitals/QV03PD5A,133,,0,mmHg,LAB_RESULT
# 118,1997-07-04,Vitals/N8GC66J0,172,,7,mmHg,LAB_RESULT
# 118,1997-08-02,Vitals/WXF7SUD8,136,,12,mmHg,LAB_RESULT
# 118,1997-08-15,Vitals/X5EA7Q0R,155,,7,mmHg,LAB_RESULT
# 119,1990-06-23,Birth/Birth,,,1,,PATIENT
# 119,1990-06-23,Gender/Gender,F,,1,,PATIENT
# 119,1990-06-23,Race/Race,White,,1,,PATIENT
# 119,1990-08-24,ICD10CM/46KSLW4Q,,,16,,DIAGNOSIS
# 119,1990-11-13,ICD10CM/HY76WEA2,,,17,,DIAGNOSIS
# 119,1990-11-13,ICD10CM/ZTWUBT2L,,,0,,DIAGNOSIS
# 119,1990-11-15,ICD10CM/K6MU10JM,,,9,,DIAGNOSIS
# 119,1990-11-25,ICD10CM/7771IGP0,,,4,,DIAGNOSIS
# 119,1990-12-31,CPT/2AV4OSYA,,,6,,PROCEDURES
# 119,1991-02-13,CPT/4SSCZSO5,,,1,,PROCEDURES
# 119,1991-03-03,CPT/YCMIHDKB,,,13,,PROCEDURES
# 119,1991-03-20,CPT/CP28P8IZ,,,7,,PROCEDURES
# 119,1991-05-06,CPT/G9VDRSTB,,,14,,PROCEDURES
# 119,1991-07-07,CPT/1H4K3JOR,,,20,,PROCEDURES
# 119,1991-08-28,CPT/2BN2WGSE,,,17,,PROCEDURES
# 119,1991-11-27,CPT/2PX10PJK,,,13,,PROCEDURES
# 119,1992-01-22,CPT/3U1S1D5Q,,,11,,PROCEDURES
# 119,1992-03-30,Drug/XLADVFK4,,21,0,mg,MED_ORDER
# 119,1992-05-13,Drug/S0KU3GV5,,31,13,mg,MED_ORDER
# 119,1992-05-24,Drug/DBQGZVWT,,47,10,mg,MED_ORDER
# 119,1992-06-29,Drug/J8UQE2GV,,34,15,mg,MED_ORDER
# 119,1992-09-24,Drug/AAEZTSSA,,31,11,mg,MED_ORDER
# 119,1992-11-20,Drug/PDAE868T,,41,6,mg,MED_ORDER
# 119,1992-12-06,Drug/1R1I5U7S,,36,11,mg,MED_ORDER
# 119,1993-01-05,Vitals/LR2F7X3O,81,,7,mmHg,LAB_RESULT
# 119,1993-01-15,Vitals/HHSM3TKL,115,,17,mmHg,LAB_RESULT
# 119,1993-03-17,Vitals/BTHJP8VV,116,,5,mmHg,LAB_RESULT
# 120,1991-02-27,Birth/Birth,,,1,,PATIENT
# 120,1991-02-27,Gender/Gender,F,,1,,PATIENT
# 120,1991-02-27,Race/Race,White,,1,,PATIENT
# 120,1991-04-16,ICD10CM/W1FOFN3E,,,4,,DIAGNOSIS
# 120,1991-07-07,ICD10CM/IRB5RTH9,,,1,,DIAGNOSIS
# 120,1991-08-09,ICD10CM/EB6BU94T,,,18,,DIAGNOSIS
# 120,1991-10-04,ICD10CM/WDH3UP8R,,,13,,DIAGNOSIS
# 120,1991-10-25,CPT/LMCTMQJA,,,9,,PROCEDURES
# 120,1992-01-01,CPT/4OM7D57S,,,3,,PROCEDURES
# 120,1992-04-05,CPT/62NPXB9I,,,13,,PROCEDURES
# 120,1992-04-19,CPT/507D485P,,,11,,PROCEDURES
# 120,1992-07-24,CPT/22DZBJQV,,,13,,PROCEDURES
# 120,1992-10-14,CPT/WBHI02J4,,,4,,PROCEDURES
# 120,1993-01-13,Drug/8I40OTI5,,33,19,mg,MED_ORDER
# 120,1993-03-01,Drug/VW0AN256,,34,18,mg,MED_ORDER
# 120,1993-04-16,Drug/5N6QA93W,,48,15,mg,MED_ORDER
# 120,1993-06-22,Drug/B4G5BXGW,,37,0,mg,MED_ORDER
# 120,1993-08-11,Drug/ZH4ZZLVQ,,33,14,mg,MED_ORDER
# 120,1993-10-02,Drug/OPW9KQYN,,21,0,mg,MED_ORDER
# 120,1993-11-09,Drug/9XJ0KJ1L,,38,12,mg,MED_ORDER
# 120,1994-01-26,Drug/TNG5H8AG,,13,2,mg,MED_ORDER
# 120,1994-02-01,Drug/3B7OXZR3,,14,6,mg,MED_ORDER
# 120,1994-03-07,Drug/X6QTLLNI,,15,6,mg,MED_ORDER
# 120,1994-05-14,Vitals/VBLP8Q9D,152,,14,mmHg,LAB_RESULT
# 120,1994-07-04,Vitals/IH6UTUND,182,,20,mmHg,LAB_RESULT
# 120,1994-07-19,Vitals/KT76ZUJU,149,,4,mmHg,LAB_RESULT
# 120,1994-08-21,Vitals/04FUNE85,144,,10,mmHg,LAB_RESULT
# 120,1994-09-26,Vitals/8F9TTET1,85,,17,mmHg,LAB_RESULT
# 120,1994-11-23,Vitals/B0TMEYR5,155,,3,mmHg,LAB_RESULT
# 120,1995-02-07,Vitals/CC509A2P,147,,9,mmHg,LAB_RESULT
# 120,1995-02-24,Vitals/CVYYBNJG,139,,10,mmHg,LAB_RESULT
# 120,1995-03-15,Vitals/H1FC9PKZ,196,,4,mmHg,LAB_RESULT
# 120,1995-06-07,Vitals/4F8EDE8O,199,,20,mmHg,LAB_RESULT
# 121,1990-05-11,Birth/Birth,,,1,,PATIENT
# 121,1990-05-11,Gender/Gender,M,,1,,PATIENT
# 121,1990-05-11,Race/Race,Non-White,,1,,PATIENT
# 121,1990-06-29,ICD10CM/GG6NQWL1,,,11,,DIAGNOSIS
# 121,1990-08-05,ICD10CM/3XCKACEU,,,10,,DIAGNOSIS
# 121,1990-08-10,ICD10CM/5VWI2J34,,,19,,DIAGNOSIS
# 121,1990-09-22,ICD10CM/JA9SHJV0,,,8,,DIAGNOSIS
# 121,1990-11-26,ICD10CM/RPQGVP1V,,,3,,DIAGNOSIS
# 121,1990-12-25,ICD10CM/ITLSM2EO,,,16,,DIAGNOSIS
# 121,1991-03-16,CPT/AHOFEMQB,,,19,,PROCEDURES
# 121,1991-06-13,Drug/K6DNMZEC,,10,10,mg,MED_ORDER
# 121,1991-07-27,Drug/Z356BJ50,,18,3,mg,MED_ORDER
# 121,1991-08-23,Drug/H2ZZFNX4,,38,8,mg,MED_ORDER
# 121,1991-11-19,Drug/JMYC3MA4,,26,7,mg,MED_ORDER
# 121,1991-12-06,Drug/KXIPTCLT,,29,9,mg,MED_ORDER
# 121,1991-12-12,Drug/GO7R89C2,,13,13,mg,MED_ORDER
# 121,1992-03-16,Drug/5FFTNQFQ,,45,20,mg,MED_ORDER
# 121,1992-06-16,Vitals/T6NC2M3Q,124,,2,mmHg,LAB_RESULT
# 121,1992-06-28,Vitals/FPJ78WGS,88,,13,mmHg,LAB_RESULT
# 122,1992-03-17,Birth/Birth,,,1,,PATIENT
# 122,1992-03-17,Gender/Gender,M,,1,,PATIENT
# 122,1992-03-17,Race/Race,Non-White,,1,,PATIENT
# 122,1992-05-12,ICD10CM/G0S49DQ5,,,14,,DIAGNOSIS
# 122,1992-08-12,ICD10CM/C2KXZ6YC,,,7,,DIAGNOSIS
# 122,1992-10-01,ICD10CM/E744PEIA,,,4,,DIAGNOSIS
# 122,1992-10-05,ICD10CM/AQYQ7G3Z,,,3,,DIAGNOSIS
# 122,1992-12-19,ICD10CM/9Z5BC9G7,,,4,,DIAGNOSIS
# 122,1993-01-10,ICD10CM/OXWHNHE1,,,4,,DIAGNOSIS
# 122,1993-01-18,ICD10CM/4ZUPQNUA,,,3,,DIAGNOSIS
# 122,1993-03-01,CPT/WXXYVWBM,,,1,,PROCEDURES
# 122,1993-03-10,CPT/844C14M6,,,11,,PROCEDURES
# 122,1993-05-03,CPT/PCJYVR4P,,,14,,PROCEDURES
# 122,1993-07-04,CPT/BP7JE536,,,19,,PROCEDURES
# 122,1993-08-16,CPT/T1YC68G0,,,18,,PROCEDURES
# 122,1993-10-31,CPT/6Q1QP6DJ,,,2,,PROCEDURES
# 122,1993-12-17,Drug/FZKBNM5P,,44,6,mg,MED_ORDER
# 122,1994-02-03,Drug/05QFJPCX,,25,12,mg,MED_ORDER
# 122,1994-03-04,Drug/IPXO2922,,24,8,mg,MED_ORDER
# 122,1994-05-20,Drug/C9ZL1FYB,,50,0,mg,MED_ORDER
# 122,1994-07-18,Drug/NGZEWK41,,10,5,mg,MED_ORDER
# 122,1994-07-30,Drug/HCXQRQAK,,18,2,mg,MED_ORDER
# 122,1994-09-09,Drug/I4C7NSWB,,36,0,mg,MED_ORDER
# 122,1994-10-02,Drug/O51EHTX2,,49,5,mg,MED_ORDER
# 122,1994-12-02,Vitals/XK5G7IM0,191,,1,mmHg,LAB_RESULT
# 122,1994-12-19,Vitals/U9B7D9DL,103,,17,mmHg,LAB_RESULT
# 122,1995-03-07,Vitals/0ZPREGYM,113,,17,mmHg,LAB_RESULT
# 122,1995-04-18,Vitals/J09AECP0,114,,11,mmHg,LAB_RESULT
# 122,1995-06-22,Vitals/6HLUBQIU,106,,1,mmHg,LAB_RESULT
# 122,1995-09-15,Vitals/PDW5W70O,101,,11,mmHg,LAB_RESULT
# 122,1995-10-20,Vitals/GNKV1NH3,157,,4,mmHg,LAB_RESULT
# 122,1995-12-03,Vitals/J95ZYOOQ,151,,7,mmHg,LAB_RESULT
# 123,1991-03-04,Birth/Birth,,,1,,PATIENT
# 123,1991-03-04,Gender/Gender,F,,1,,PATIENT
# 123,1991-03-04,Race/Race,White,,1,,PATIENT
# 123,1991-04-27,ICD10CM/VRZ490HU,,,17,,DIAGNOSIS
# 123,1991-07-25,ICD10CM/SKOBNIO7,,,8,,DIAGNOSIS
# 123,1991-09-29,ICD10CM/RPZLGXYV,,,15,,DIAGNOSIS
# 123,1992-01-04,ICD10CM/LG0EFM7S,,,17,,DIAGNOSIS
# 123,1992-02-26,ICD10CM/I091BSQN,,,2,,DIAGNOSIS
# 123,1992-05-08,ICD10CM/Y4F0BJZ4,,,6,,DIAGNOSIS
# 123,1992-07-17,ICD10CM/FV0AEWVE,,,11,,DIAGNOSIS
# 123,1992-08-08,ICD10CM/F9ZTV98W,,,15,,DIAGNOSIS
# 123,1992-11-14,ICD10CM/N4Q44EYF,,,2,,DIAGNOSIS
# 123,1993-01-27,CPT/1C99951F,,,9,,PROCEDURES
# 123,1993-03-09,CPT/EZEUMB0E,,,17,,PROCEDURES
# 123,1993-05-21,CPT/KFZ5LWL6,,,16,,PROCEDURES
# 123,1993-07-29,CPT/JWG77OWQ,,,1,,PROCEDURES
# 123,1993-11-04,CPT/KOUVY1LO,,,7,,PROCEDURES
# 123,1994-01-09,CPT/CEQ4537S,,,1,,PROCEDURES
# 123,1994-04-11,CPT/UX68MXCQ,,,17,,PROCEDURES
# 123,1994-05-24,CPT/F2MLIKHT,,,11,,PROCEDURES
# 123,1994-07-05,Drug/3OYQD784,,31,0,mg,MED_ORDER
# 123,1994-08-31,Drug/6MPYBRJR,,50,11,mg,MED_ORDER
# 123,1994-10-16,Drug/GHCKTTX4,,31,6,mg,MED_ORDER
# 123,1995-01-13,Drug/HFCICKM2,,32,12,mg,MED_ORDER
# 123,1995-04-12,Vitals/5PX5Q800,126,,12,mmHg,LAB_RESULT
# 123,1995-07-01,Vitals/HO4WXIL6,129,,18,mmHg,LAB_RESULT
# 123,1995-07-03,Vitals/F5RECZY6,128,,12,mmHg,LAB_RESULT
# 123,1995-07-26,Vitals/D3IGNJSY,83,,16,mmHg,LAB_RESULT
# 123,1995-09-02,Vitals/HE70E3YR,196,,19,mmHg,LAB_RESULT
# 123,1995-09-08,Vitals/ETAXKX84,124,,1,mmHg,LAB_RESULT
# 124,1992-05-29,Birth/Birth,,,1,,PATIENT
# 124,1992-05-29,Gender/Gender,M,,1,,PATIENT
# 124,1992-05-29,Race/Race,Non-White,,1,,PATIENT
# 124,1992-07-12,ICD10CM/QL383XKB,,,2,,DIAGNOSIS
# 124,1992-09-11,ICD10CM/6GG39B3K,,,17,,DIAGNOSIS
# 124,1992-10-20,ICD10CM/CVTMKFS2,,,5,,DIAGNOSIS
# 124,1993-01-10,ICD10CM/36JG1K80,,,17,,DIAGNOSIS
# 124,1993-01-28,ICD10CM/G50A3TJC,,,8,,DIAGNOSIS
# 124,1993-04-14,ICD10CM/RJD95YD9,,,19,,DIAGNOSIS
# 124,1993-06-16,ICD10CM/J7FN92LV,,,11,,DIAGNOSIS
# 124,1993-08-12,CPT/5MACVKNE,,,9,,PROCEDURES
# 124,1993-08-22,CPT/EVB9Y26O,,,11,,PROCEDURES
# 124,1993-11-18,CPT/HKL33UIK,,,2,,PROCEDURES
# 124,1994-02-18,CPT/D37MPEM3,,,20,,PROCEDURES
# 124,1994-03-18,CPT/M7HXD7PN,,,17,,PROCEDURES
# 124,1994-06-07,CPT/PN483IR0,,,19,,PROCEDURES
# 124,1994-08-03,CPT/IHHGTUOR,,,19,,PROCEDURES
# 124,1994-08-13,CPT/A56GFI3J,,,18,,PROCEDURES
# 124,1994-11-15,CPT/WAHV1DTO,,,7,,PROCEDURES
# 124,1994-12-20,CPT/VKGWV97G,,,12,,PROCEDURES
# 124,1995-01-13,Drug/RYWWTKZB,,10,15,mg,MED_ORDER
# 124,1995-01-15,Drug/XXIY3J1B,,49,14,mg,MED_ORDER
# 124,1995-01-24,Drug/XTLR5S2A,,12,17,mg,MED_ORDER
# 124,1995-01-29,Drug/Y4GFYYKF,,19,5,mg,MED_ORDER
# 124,1995-03-15,Drug/UVBX2GW3,,26,3,mg,MED_ORDER
# 124,1995-05-30,Drug/SRXLVBD2,,31,19,mg,MED_ORDER
# 124,1995-08-11,Drug/XB0EM5LI,,24,7,mg,MED_ORDER
# 124,1995-10-09,Drug/NNDQ4DGA,,46,9,mg,MED_ORDER
# 124,1995-12-27,Vitals/3SNIBQJI,109,,5,mmHg,LAB_RESULT
# 124,1996-01-19,Vitals/GCD660A8,176,,16,mmHg,LAB_RESULT
# 124,1996-03-18,Vitals/H51Y3EUO,112,,14,mmHg,LAB_RESULT
# 124,1996-03-19,Vitals/Z3ETDWJ7,149,,14,mmHg,LAB_RESULT
# 124,1996-05-16,Vitals/SZF9TJFY,90,,10,mmHg,LAB_RESULT
# 124,1996-08-09,Vitals/P3T03CE1,182,,16,mmHg,LAB_RESULT
# 124,1996-10-20,Vitals/HVQVOWH4,104,,1,mmHg,LAB_RESULT
# 125,1990-04-30,Birth/Birth,,,1,,PATIENT
# 125,1990-04-30,Gender/Gender,M,,1,,PATIENT
# 125,1990-04-30,Race/Race,Non-White,,1,,PATIENT
# 125,1990-07-19,ICD10CM/Q2UVAQIU,,,19,,DIAGNOSIS
# 125,1990-09-12,ICD10CM/LILQ05SA,,,17,,DIAGNOSIS
# 125,1990-10-02,ICD10CM/BOD0Q0A7,,,17,,DIAGNOSIS
# 125,1990-10-07,ICD10CM/3P3WKNLQ,,,12,,DIAGNOSIS
# 125,1990-10-08,ICD10CM/KTL7Y70I,,,13,,DIAGNOSIS
# 125,1990-10-29,ICD10CM/T12N6X43,,,8,,DIAGNOSIS
# 125,1991-01-23,ICD10CM/W9R2TBIA,,,16,,DIAGNOSIS
# 125,1991-03-20,CPT/P07BNNPH,,,6,,PROCEDURES
# 125,1991-04-18,CPT/6SFBNSCT,,,5,,PROCEDURES
# 125,1991-04-23,CPT/OHSMPS9O,,,19,,PROCEDURES
# 125,1991-06-07,CPT/SF3EGI3R,,,2,,PROCEDURES
# 125,1991-08-18,CPT/QUTPJ375,,,1,,PROCEDURES
# 125,1991-09-30,CPT/EOU14SN8,,,19,,PROCEDURES
# 125,1991-11-16,CPT/HUHWGKOD,,,7,,PROCEDURES
# 125,1992-01-27,CPT/8PN9SFV7,,,20,,PROCEDURES
# 125,1992-04-02,CPT/1FQJKYFZ,,,7,,PROCEDURES
# 125,1992-06-14,Drug/JAFOI8AF,,39,6,mg,MED_ORDER
# 125,1992-08-05,Drug/20VGKP23,,26,9,mg,MED_ORDER
# 125,1992-09-06,Drug/75B7A5WD,,13,12,mg,MED_ORDER
# 125,1992-10-09,Drug/HVIDHJCB,,38,12,mg,MED_ORDER
# 125,1992-11-29,Drug/XGVXUXDD,,45,20,mg,MED_ORDER
# 125,1993-02-14,Drug/PN0CG1G0,,14,20,mg,MED_ORDER
# 125,1993-03-14,Drug/SKZ8QI0O,,31,10,mg,MED_ORDER
# 125,1993-03-19,Drug/G1MIMFGQ,,40,5,mg,MED_ORDER
# 125,1993-05-07,Drug/O4RSUJV7,,10,4,mg,MED_ORDER
# 125,1993-06-19,Drug/ZJ6AY3Y6,,18,18,mg,MED_ORDER
# 125,1993-06-19,Vitals/MA5NFF7G,177,,18,mmHg,LAB_RESULT
# 126,1990-12-02,Birth/Birth,,,1,,PATIENT
# 126,1990-12-02,Gender/Gender,F,,1,,PATIENT
# 126,1990-12-02,Race/Race,White,,1,,PATIENT
# 126,1991-01-30,ICD10CM/VSXA9261,,,12,,DIAGNOSIS
# 126,1991-05-06,ICD10CM/6D9EYPCA,,,8,,DIAGNOSIS
# 126,1991-06-29,CPT/8I3B2YOX,,,11,,PROCEDURES
# 126,1991-07-10,CPT/L1R9MRL8,,,8,,PROCEDURES
# 126,1991-07-10,CPT/AJ900AN5,,,19,,PROCEDURES
# 126,1991-09-16,Drug/YVQL0RE3,,23,17,mg,MED_ORDER
# 126,1991-12-11,Drug/5HKTX5GD,,43,5,mg,MED_ORDER
# 126,1992-01-07,Drug/KK5NFW5E,,45,2,mg,MED_ORDER
# 126,1992-02-20,Drug/F2ALP46H,,44,15,mg,MED_ORDER
# 126,1992-05-27,Vitals/WW9FF7AI,163,,3,mmHg,LAB_RESULT
# 126,1992-08-25,Vitals/OA0KDA3Q,185,,19,mmHg,LAB_RESULT
# 126,1992-10-09,Vitals/9QJ0HYET,82,,18,mmHg,LAB_RESULT
# 126,1993-01-09,Vitals/ZFDBHWP4,169,,4,mmHg,LAB_RESULT
# 126,1993-04-02,Vitals/7HMYG166,123,,14,mmHg,LAB_RESULT
# 127,1991-08-08,Birth/Birth,,,1,,PATIENT
# 127,1991-08-08,Gender/Gender,F,,1,,PATIENT
# 127,1991-08-08,Race/Race,White,,1,,PATIENT
# 127,1991-09-17,ICD10CM/IGMX33V1,,,16,,DIAGNOSIS
# 127,1991-11-23,ICD10CM/54JJHKYQ,,,2,,DIAGNOSIS
# 127,1992-02-26,ICD10CM/PEFC6UDK,,,20,,DIAGNOSIS
# 127,1992-03-15,ICD10CM/II61WLNL,,,13,,DIAGNOSIS
# 127,1992-06-07,ICD10CM/7T8K2YIX,,,1,,DIAGNOSIS
# 127,1992-08-03,CPT/DGU6SKJL,,,17,,PROCEDURES
# 127,1992-08-14,CPT/WKR2ROXC,,,9,,PROCEDURES
# 127,1992-10-09,CPT/QE5Y2L9D,,,19,,PROCEDURES
# 127,1993-01-10,CPT/XV996ZTR,,,2,,PROCEDURES
# 127,1993-03-24,CPT/AQOO68DB,,,10,,PROCEDURES
# 127,1993-06-25,CPT/56U9707W,,,3,,PROCEDURES
# 127,1993-09-07,CPT/Z6PGLVBO,,,13,,PROCEDURES
# 127,1993-10-25,CPT/QEZVBGBH,,,0,,PROCEDURES
# 127,1993-11-11,CPT/HZL5D4XT,,,4,,PROCEDURES
# 127,1993-12-04,Drug/IGRXGCVR,,42,20,mg,MED_ORDER
# 127,1994-01-21,Drug/OK9RQJOG,,13,10,mg,MED_ORDER
# 127,1994-02-27,Drug/OHB7C7IP,,37,9,mg,MED_ORDER
# 127,1994-04-03,Drug/TDK23W5K,,34,18,mg,MED_ORDER
# 127,1994-06-28,Drug/QZ8WU8UX,,37,19,mg,MED_ORDER
# 127,1994-07-10,Drug/HNGPE3PV,,13,19,mg,MED_ORDER
# 127,1994-10-01,Drug/Y2314PGL,,35,17,mg,MED_ORDER
# 127,1994-10-01,Drug/PLH2O8NK,,45,10,mg,MED_ORDER
# 127,1994-12-16,Drug/LVVAHLZA,,42,5,mg,MED_ORDER
# 127,1995-02-26,Vitals/G0EDTS82,83,,1,mmHg,LAB_RESULT
# 127,1995-03-07,Vitals/3YZXKE3C,188,,4,mmHg,LAB_RESULT
# 127,1995-05-28,Vitals/MYZD6D0L,196,,2,mmHg,LAB_RESULT
# 127,1995-08-09,Vitals/WNP9ZNVD,154,,20,mmHg,LAB_RESULT
# 127,1995-10-07,Vitals/UV6H6OEW,97,,20,mmHg,LAB_RESULT
# 127,1995-11-04,Vitals/HMKF6YHH,149,,3,mmHg,LAB_RESULT
# 127,1995-12-10,Vitals/RJWFCA1T,143,,10,mmHg,LAB_RESULT
# 127,1996-02-28,Vitals/IPY8MYTK,187,,12,mmHg,LAB_RESULT
# 128,1992-03-19,Birth/Birth,,,1,,PATIENT
# 128,1992-03-19,Gender/Gender,F,,1,,PATIENT
# 128,1992-03-19,Race/Race,White,,1,,PATIENT
# 128,1992-04-15,ICD10CM/2Q0TVEMJ,,,9,,DIAGNOSIS
# 128,1992-06-22,ICD10CM/FSIUTQGU,,,14,,DIAGNOSIS
# 128,1992-06-28,CPT/AT1E5BDX,,,7,,PROCEDURES
# 128,1992-08-29,Drug/I6FDHJAJ,,47,15,mg,MED_ORDER
# 128,1992-11-04,Drug/42KKMRCI,,46,15,mg,MED_ORDER
# 128,1992-11-09,Drug/UF6HNNNR,,39,14,mg,MED_ORDER
# 128,1993-02-14,Drug/HP800A2Q,,28,10,mg,MED_ORDER
# 128,1993-03-03,Drug/QH4A6D93,,30,13,mg,MED_ORDER
# 128,1993-05-15,Drug/WT784Z3G,,50,1,mg,MED_ORDER
# 128,1993-07-02,Drug/KRRQRFLP,,12,14,mg,MED_ORDER
# 128,1993-08-05,Vitals/W89UMBNV,115,,17,mmHg,LAB_RESULT
# 129,1990-04-22,Birth/Birth,,,1,,PATIENT
# 129,1990-04-22,Gender/Gender,F,,1,,PATIENT
# 129,1990-04-22,Race/Race,White,,1,,PATIENT
# 129,1990-06-13,ICD10CM/LOEIU0P6,,,5,,DIAGNOSIS
# 129,1990-08-05,ICD10CM/EDQCY0NT,,,4,,DIAGNOSIS
# 129,1990-09-28,ICD10CM/C69DMEJ1,,,18,,DIAGNOSIS
# 129,1990-09-30,CPT/25PEFPTB,,,4,,PROCEDURES
# 129,1990-09-30,CPT/QBD7GGAK,,,12,,PROCEDURES
# 129,1990-10-07,CPT/M18X66RX,,,16,,PROCEDURES
# 129,1990-10-27,CPT/X0ST799W,,,16,,PROCEDURES
# 129,1990-11-21,CPT/I8FF3I1M,,,16,,PROCEDURES
# 129,1991-01-21,CPT/O1IN639O,,,4,,PROCEDURES
# 129,1991-05-01,CPT/PLVF4POL,,,3,,PROCEDURES
# 129,1991-08-01,CPT/MX2EZ4KC,,,20,,PROCEDURES
# 129,1991-10-09,Drug/TJ8XPPXS,,45,0,mg,MED_ORDER
# 129,1991-12-01,Drug/BDV6OURN,,39,16,mg,MED_ORDER
# 129,1991-12-15,Drug/SUSDMKUT,,24,14,mg,MED_ORDER
# 129,1992-02-18,Vitals/65P3WX3G,198,,5,mmHg,LAB_RESULT
# 129,1992-03-10,Vitals/AJJ8WMDA,138,,10,mmHg,LAB_RESULT
# 129,1992-05-26,Vitals/NB9E4ZSL,191,,5,mmHg,LAB_RESULT
# 129,1992-07-19,Vitals/QNE1AHTH,162,,9,mmHg,LAB_RESULT
# 129,1992-09-18,Vitals/7L2R1FGN,121,,0,mmHg,LAB_RESULT
# 129,1992-11-14,Vitals/CML7SBEA,167,,0,mmHg,LAB_RESULT
# 130,1992-01-22,Birth/Birth,,,1,,PATIENT
# 130,1992-01-22,Gender/Gender,M,,1,,PATIENT
# 130,1992-01-22,Race/Race,Non-White,,1,,PATIENT
# 130,1992-02-17,ICD10CM/34JE9S8U,,,13,,DIAGNOSIS
# 130,1992-04-04,CPT/NJ541HDX,,,15,,PROCEDURES
# 130,1992-04-17,CPT/QJ2T76W5,,,5,,PROCEDURES
# 130,1992-06-13,CPT/J9ID7SR2,,,9,,PROCEDURES
# 130,1992-09-14,CPT/S5RWMTBU,,,6,,PROCEDURES
# 130,1992-11-29,CPT/V3GEOCZ0,,,0,,PROCEDURES
# 130,1992-12-31,Drug/8RBBTHCC,,11,0,mg,MED_ORDER
# 130,1993-02-01,Drug/SCBGGD9Y,,16,7,mg,MED_ORDER
# 130,1993-05-12,Drug/3F2QJ8VF,,16,1,mg,MED_ORDER
# 130,1993-08-10,Drug/N3UGMB6Z,,46,4,mg,MED_ORDER
# 130,1993-08-22,Drug/M1QEFXPB,,17,9,mg,MED_ORDER
# 130,1993-09-04,Drug/2O2ZDQUJ,,34,10,mg,MED_ORDER
# 130,1993-10-24,Drug/3W52GY8E,,50,1,mg,MED_ORDER
# 130,1993-12-25,Vitals/G3HRCK4T,112,,18,mmHg,LAB_RESULT
# 131,1992-07-21,Birth/Birth,,,1,,PATIENT
# 131,1992-07-21,Gender/Gender,M,,1,,PATIENT
# 131,1992-07-21,Race/Race,Non-White,,1,,PATIENT
# 131,1992-09-07,ICD10CM/DYJR51N6,,,6,,DIAGNOSIS
# 131,1992-09-23,CPT/JVOC24K7,,,2,,PROCEDURES
# 131,1992-09-29,CPT/GSR22E97,,,1,,PROCEDURES
# 131,1993-01-04,Drug/BRQ4D5Q7,,18,17,mg,MED_ORDER
# 131,1993-01-07,Drug/8E8PTR24,,47,6,mg,MED_ORDER
# 131,1993-03-29,Drug/Z54NCGOF,,43,14,mg,MED_ORDER
# 131,1993-04-22,Drug/CQM5AEUU,,13,8,mg,MED_ORDER
# 131,1993-07-19,Drug/RZ6PN9QD,,38,18,mg,MED_ORDER
# 131,1993-07-28,Drug/RCV65RXU,,43,9,mg,MED_ORDER
# 131,1993-08-07,Drug/OK299L1A,,19,3,mg,MED_ORDER
# 131,1993-09-12,Drug/Z4UFQ6U2,,27,1,mg,MED_ORDER
# 131,1993-11-26,Vitals/87NVIF71,147,,11,mmHg,LAB_RESULT
# 131,1993-12-31,Vitals/N5HH258T,125,,0,mmHg,LAB_RESULT
# 131,1994-03-03,Vitals/857S432T,164,,15,mmHg,LAB_RESULT
# 131,1994-03-28,Vitals/Z4VDONSB,187,,16,mmHg,LAB_RESULT
# 131,1994-05-22,Vitals/3UT07NRC,108,,6,mmHg,LAB_RESULT
# 131,1994-06-21,Vitals/PBQKD7ND,109,,2,mmHg,LAB_RESULT
# 131,1994-07-05,Vitals/3091H1YO,138,,6,mmHg,LAB_RESULT
# 131,1994-08-20,Vitals/UC6N8LYO,125,,13,mmHg,LAB_RESULT
# 132,1990-04-11,Birth/Birth,,,1,,PATIENT
# 132,1990-04-11,Gender/Gender,F,,1,,PATIENT
# 132,1990-04-11,Race/Race,White,,1,,PATIENT
# 132,1990-05-22,ICD10CM/1SA41B40,,,20,,DIAGNOSIS
# 132,1990-05-26,ICD10CM/NG3CBOOB,,,9,,DIAGNOSIS
# 132,1990-08-13,ICD10CM/PXNEFAMA,,,12,,DIAGNOSIS
# 132,1990-10-08,ICD10CM/0GJ3C16F,,,5,,DIAGNOSIS
# 132,1990-12-11,ICD10CM/BWR4N0YV,,,4,,DIAGNOSIS
# 132,1991-01-22,ICD10CM/696IIK5U,,,4,,DIAGNOSIS
# 132,1991-03-09,ICD10CM/JMGRRU51,,,7,,DIAGNOSIS
# 132,1991-06-14,CPT/ZF1ITNSY,,,17,,PROCEDURES
# 132,1991-06-28,CPT/1YSG9C4H,,,15,,PROCEDURES
# 132,1991-09-03,CPT/JKEVIH1S,,,7,,PROCEDURES
# 132,1991-10-09,CPT/BWVWIH7D,,,4,,PROCEDURES
# 132,1992-01-16,CPT/0KI94Q67,,,9,,PROCEDURES
# 132,1992-02-24,CPT/0QSQTYWU,,,10,,PROCEDURES
# 132,1992-05-16,CPT/X8FWHF0R,,,8,,PROCEDURES
# 132,1992-07-07,CPT/JAQLYN0A,,,19,,PROCEDURES
# 132,1992-08-17,CPT/6GFDXRKG,,,16,,PROCEDURES
# 132,1992-09-10,Drug/BUTZRZ4G,,36,2,mg,MED_ORDER
# 132,1992-11-21,Drug/E2G78S7O,,12,10,mg,MED_ORDER
# 132,1992-12-28,Drug/ABR1GP7F,,26,3,mg,MED_ORDER
# 132,1993-03-07,Drug/M9CV34Q9,,37,8,mg,MED_ORDER
# 132,1993-03-07,Drug/X8A6ULE2,,26,16,mg,MED_ORDER
# 132,1993-05-21,Drug/TNZO78KB,,21,12,mg,MED_ORDER
# 132,1993-07-02,Drug/2RHZCQ9V,,24,10,mg,MED_ORDER
# 132,1993-08-04,Drug/GDPQZGUE,,25,3,mg,MED_ORDER
# 132,1993-10-25,Vitals/POA79VQZ,148,,3,mmHg,LAB_RESULT
# 132,1993-11-20,Vitals/J88YU83T,105,,9,mmHg,LAB_RESULT
# 132,1993-12-11,Vitals/VGADVBJU,85,,16,mmHg,LAB_RESULT
# 132,1994-01-26,Vitals/WS8MQG0C,117,,6,mmHg,LAB_RESULT
# 132,1994-03-08,Vitals/VAOZ7ZSW,156,,2,mmHg,LAB_RESULT
# 132,1994-04-14,Vitals/Q2EWGLQG,121,,3,mmHg,LAB_RESULT
# 133,1992-07-22,Birth/Birth,,,1,,PATIENT
# 133,1992-07-22,Gender/Gender,F,,1,,PATIENT
# 133,1992-07-22,Race/Race,White,,1,,PATIENT
# 133,1992-09-27,ICD10CM/H1WLCURG,,,7,,DIAGNOSIS
# 133,1992-12-01,ICD10CM/2NL2J6KL,,,8,,DIAGNOSIS
# 133,1993-02-05,CPT/DGDK4LWH,,,12,,PROCEDURES
# 133,1993-03-10,CPT/R6W6D3O1,,,6,,PROCEDURES
# 133,1993-03-29,CPT/Z8QUVGVP,,,16,,PROCEDURES
# 133,1993-05-17,CPT/35HL6RGL,,,16,,PROCEDURES
# 133,1993-06-29,CPT/GTHQF36F,,,14,,PROCEDURES
# 133,1993-09-30,Drug/MEUJPOK4,,13,8,mg,MED_ORDER
# 133,1993-11-24,Drug/DCND17TI,,33,7,mg,MED_ORDER
# 133,1993-11-26,Drug/P0A53RYO,,20,5,mg,MED_ORDER
# 133,1993-12-09,Drug/PULV675Q,,27,7,mg,MED_ORDER
# 133,1994-02-16,Drug/X53TGQFR,,35,19,mg,MED_ORDER
# 133,1994-03-12,Vitals/DLXVNM91,138,,20,mmHg,LAB_RESULT
# 133,1994-05-13,Vitals/YY7VC2CP,123,,8,mmHg,LAB_RESULT
# 133,1994-06-10,Vitals/EL7J6RMQ,196,,18,mmHg,LAB_RESULT
# 133,1994-06-30,Vitals/VRS7C6G9,131,,18,mmHg,LAB_RESULT
# 133,1994-09-21,Vitals/AHI7NLGV,184,,20,mmHg,LAB_RESULT
# 133,1994-10-25,Vitals/V40CYYFU,124,,4,mmHg,LAB_RESULT
# 133,1994-12-27,Vitals/DL25RCZ0,138,,8,mmHg,LAB_RESULT
# 134,1991-10-24,Birth/Birth,,,1,,PATIENT
# 134,1991-10-24,Gender/Gender,F,,1,,PATIENT
# 134,1991-10-24,Race/Race,White,,1,,PATIENT
# 134,1991-12-13,ICD10CM/ZR4KLNCU,,,20,,DIAGNOSIS
# 134,1992-01-20,CPT/7QPRVB97,,,15,,PROCEDURES
# 134,1992-02-11,CPT/R6WK5TIL,,,13,,PROCEDURES
# 134,1992-03-06,CPT/U9GSDWGW,,,0,,PROCEDURES
# 134,1992-05-16,CPT/8VOM1B2X,,,4,,PROCEDURES
# 134,1992-06-13,Drug/EEVV30CP,,44,2,mg,MED_ORDER
# 134,1992-06-16,Vitals/YK6O5P7G,105,,0,mmHg,LAB_RESULT
# 134,1992-08-20,Vitals/Y0FX7QB4,83,,4,mmHg,LAB_RESULT
# 134,1992-09-09,Vitals/GZEMOFTH,90,,16,mmHg,LAB_RESULT
# 134,1992-12-15,Vitals/IFWQIIAM,192,,7,mmHg,LAB_RESULT
# 134,1992-12-22,Vitals/WEM8SIPM,179,,17,mmHg,LAB_RESULT
# 134,1993-02-03,Vitals/CMV9UY1T,135,,10,mmHg,LAB_RESULT
# 134,1993-02-13,Vitals/BM974SKT,100,,6,mmHg,LAB_RESULT
# 134,1993-05-23,Vitals/V7AN87DH,164,,1,mmHg,LAB_RESULT
# 134,1993-07-08,Vitals/EJQBCV0Y,139,,14,mmHg,LAB_RESULT
# 135,1990-10-28,Birth/Birth,,,1,,PATIENT
# 135,1990-10-28,Gender/Gender,F,,1,,PATIENT
# 135,1990-10-28,Race/Race,White,,1,,PATIENT
# 135,1990-11-17,ICD10CM/OZYYV3B1,,,16,,DIAGNOSIS
# 135,1991-02-19,ICD10CM/QPYR9TAA,,,9,,DIAGNOSIS
# 135,1991-05-23,CPT/CQDJJX3M,,,20,,PROCEDURES
# 135,1991-08-15,CPT/3EC0AYWA,,,11,,PROCEDURES
# 135,1991-11-01,CPT/GLPFWW5I,,,7,,PROCEDURES
# 135,1992-01-01,Drug/H6O6I4B9,,43,17,mg,MED_ORDER
# 135,1992-02-12,Drug/CYM8OAOZ,,33,8,mg,MED_ORDER
# 135,1992-03-29,Drug/5YN7MNDW,,18,1,mg,MED_ORDER
# 135,1992-06-20,Drug/MZF7ZO84,,23,16,mg,MED_ORDER
# 135,1992-08-29,Drug/L1ED0S4E,,29,19,mg,MED_ORDER
# 135,1992-12-02,Drug/GHR3KFNJ,,43,18,mg,MED_ORDER
# 135,1993-03-09,Drug/1VRH3RYQ,,38,6,mg,MED_ORDER
# 135,1993-04-04,Vitals/QLRJ3M0Z,195,,3,mmHg,LAB_RESULT
# 136,1990-05-23,Birth/Birth,,,1,,PATIENT
# 136,1990-05-23,Gender/Gender,M,,1,,PATIENT
# 136,1990-05-23,Race/Race,Non-White,,1,,PATIENT
# 136,1990-06-24,ICD10CM/TEAOUS19,,,18,,DIAGNOSIS
# 136,1990-08-14,ICD10CM/I5R35Z5F,,,18,,DIAGNOSIS
# 136,1990-10-09,ICD10CM/CVLBRRVQ,,,11,,DIAGNOSIS
# 136,1990-10-13,ICD10CM/1IGI8EYG,,,16,,DIAGNOSIS
# 136,1991-01-19,ICD10CM/3QSQFJL3,,,15,,DIAGNOSIS
# 136,1991-03-11,ICD10CM/8AQWZ7M4,,,13,,DIAGNOSIS
# 136,1991-05-10,ICD10CM/L7T61KP1,,,14,,DIAGNOSIS
# 136,1991-06-16,CPT/DVF0G4F6,,,11,,PROCEDURES
# 136,1991-09-03,Drug/7O9Q3NQO,,41,4,mg,MED_ORDER
# 136,1991-09-03,Drug/OCC7RT3T,,16,1,mg,MED_ORDER
# 136,1991-12-02,Vitals/99XZIVIU,174,,6,mmHg,LAB_RESULT
# 136,1992-03-08,Vitals/3G2DUR9M,154,,16,mmHg,LAB_RESULT
# 136,1992-03-28,Vitals/T51M8N1Z,89,,1,mmHg,LAB_RESULT
# 137,1991-03-05,Birth/Birth,,,1,,PATIENT
# 137,1991-03-05,Gender/Gender,F,,1,,PATIENT
# 137,1991-03-05,Race/Race,White,,1,,PATIENT
# 137,1991-05-12,ICD10CM/UVYC25AH,,,6,,DIAGNOSIS
# 137,1991-06-13,ICD10CM/5497J40Z,,,9,,DIAGNOSIS
# 137,1991-08-25,ICD10CM/QFLAH13A,,,5,,DIAGNOSIS
# 137,1991-10-07,ICD10CM/J1LGV88J,,,20,,DIAGNOSIS
# 137,1991-12-24,ICD10CM/OS0MXCCM,,,3,,DIAGNOSIS
# 137,1992-02-26,ICD10CM/PB2VFMRI,,,2,,DIAGNOSIS
# 137,1992-05-30,ICD10CM/VZU9B26A,,,17,,DIAGNOSIS
# 137,1992-07-01,CPT/EMBZDJ2I,,,15,,PROCEDURES
# 137,1992-09-09,CPT/L9ME71B7,,,2,,PROCEDURES
# 137,1992-11-27,CPT/W18DXL6E,,,6,,PROCEDURES
# 137,1993-03-06,CPT/GYR1280T,,,4,,PROCEDURES
# 137,1993-03-20,CPT/IMR4KCP2,,,0,,PROCEDURES
# 137,1993-03-23,Drug/JUCFUSRY,,23,19,mg,MED_ORDER
# 137,1993-06-06,Drug/AOE41HRH,,39,17,mg,MED_ORDER
# 137,1993-06-06,Drug/U9G3YO8U,,43,7,mg,MED_ORDER
# 137,1993-07-15,Drug/4251BTCK,,25,16,mg,MED_ORDER
# 137,1993-08-25,Drug/FBX1M4IX,,41,8,mg,MED_ORDER
# 137,1993-10-02,Drug/LA2BK5Q8,,21,20,mg,MED_ORDER
# 137,1993-11-26,Drug/UGAOCEJH,,22,4,mg,MED_ORDER
# 137,1994-01-08,Vitals/QDWJ1TKB,153,,11,mmHg,LAB_RESULT
# 137,1994-01-31,Vitals/QEOC2YAP,101,,16,mmHg,LAB_RESULT
# 137,1994-03-09,Vitals/7BTOEC3N,94,,12,mmHg,LAB_RESULT
# 137,1994-04-15,Vitals/7OF9PQHN,179,,17,mmHg,LAB_RESULT
# 137,1994-06-02,Vitals/DZOWAMHG,151,,16,mmHg,LAB_RESULT
# 138,1992-05-03,Birth/Birth,,,1,,PATIENT
# 138,1992-05-03,Gender/Gender,F,,1,,PATIENT
# 138,1992-05-03,Race/Race,White,,1,,PATIENT
# 138,1992-05-16,ICD10CM/TXK86W73,,,13,,DIAGNOSIS
# 138,1992-07-18,ICD10CM/73CTBAXC,,,9,,DIAGNOSIS
# 138,1992-08-19,ICD10CM/H61Y6NGD,,,17,,DIAGNOSIS
# 138,1992-08-29,ICD10CM/TXMD8RBO,,,20,,DIAGNOSIS
# 138,1992-10-15,ICD10CM/ZEJVSIIK,,,12,,DIAGNOSIS
# 138,1992-11-28,ICD10CM/WMYJMZQ7,,,20,,DIAGNOSIS
# 138,1993-02-10,CPT/XG9612U2,,,14,,PROCEDURES
# 138,1993-04-11,CPT/SMH4RP67,,,13,,PROCEDURES
# 138,1993-06-08,CPT/121M7S2D,,,6,,PROCEDURES
# 138,1993-09-01,CPT/N7DCCWZ8,,,7,,PROCEDURES
# 138,1993-09-14,CPT/JCNNB1RX,,,19,,PROCEDURES
# 138,1993-10-22,CPT/1B14X9HK,,,17,,PROCEDURES
# 138,1993-12-14,CPT/YY2UECNE,,,14,,PROCEDURES
# 138,1994-02-10,CPT/OXOATS1J,,,10,,PROCEDURES
# 138,1994-02-22,CPT/BU0UMP47,,,7,,PROCEDURES
# 138,1994-03-01,Drug/FKVN4YFR,,14,4,mg,MED_ORDER
# 138,1994-04-09,Drug/JAAKZEU7,,23,3,mg,MED_ORDER
# 138,1994-06-24,Vitals/DVUD7Q5Q,119,,10,mmHg,LAB_RESULT
# 138,1994-07-18,Vitals/2GZQW1ED,81,,17,mmHg,LAB_RESULT
# 138,1994-08-21,Vitals/MKB6NPBZ,152,,10,mmHg,LAB_RESULT
# 138,1994-09-24,Vitals/9PXI7KDJ,170,,9,mmHg,LAB_RESULT
# 138,1994-11-09,Vitals/EFNQ42BU,185,,1,mmHg,LAB_RESULT
# 139,1992-07-15,Birth/Birth,,,1,,PATIENT
# 139,1992-07-15,Gender/Gender,F,,1,,PATIENT
# 139,1992-07-15,Race/Race,White,,1,,PATIENT
# 139,1992-08-16,ICD10CM/3DKNTLIF,,,13,,DIAGNOSIS
# 139,1992-09-22,ICD10CM/JBYKNLUM,,,6,,DIAGNOSIS
# ...
# 181,1995-07-04,Vitals/D74XVCOD,115,,0,mmHg,LAB_RESULT
# 181,1995-10-10,Vitals/11HKPLSW,157,,14,mmHg,LAB_RESULT
# 181,1995-11-11,Vitals/LHM57UBS,88,,9,mmHg,LAB_RESULT
# 181,1996-02-16,Vitals/K4DPEZQN,88,,11,mmHg,LAB_RESULT
# 181,1996-04-13,Vitals/3T1SRE6O,89,,1,mmHg,LAB_RESULT
# 181,1996-06-06,Vitals/ZIDI6PQL,156,,14,mmHg,LAB_RESULT
# 181,1996-06-12,Vitals/E2BGEXM1,112,,1,mmHg,LAB_RESULT
# 181,1996-08-06,Vitals/WUKGWHRT,109,,7,mmHg,LAB_RESULT
# 182,1992-05-15,Birth/Birth,,,1,,PATIENT
# 182,1992-05-15,Gender/Gender,F,,1,,PATIENT
# 182,1992-05-15,Race/Race,White,,1,,PATIENT
# 182,1992-06-21,ICD10CM/JCC8HVIL,,,12,,DIAGNOSIS
# 182,1992-09-27,CPT/2JJID9T3,,,17,,PROCEDURES
# 182,1992-10-03,Drug/N8F91THD,,48,8,mg,MED_ORDER
# 182,1992-12-24,Vitals/AY858UOD,105,,4,mmHg,LAB_RESULT
# 182,1993-03-04,Vitals/QHT2AKIU,179,,17,mmHg,LAB_RESULT
# 182,1993-04-02,Vitals/5QA0HJRP,163,,7,mmHg,LAB_RESULT
# 182,1993-05-28,Vitals/W6ODCC8C,100,,8,mmHg,LAB_RESULT
# 182,1993-08-12,Vitals/Q7AEOT2E,197,,9,mmHg,LAB_RESULT
# 182,1993-11-11,Vitals/IX0ASOUE,81,,11,mmHg,LAB_RESULT
# 182,1993-12-20,Vitals/V0UCMAVS,188,,18,mmHg,LAB_RESULT
# 183,1990-07-02,Birth/Birth,,,1,,PATIENT
# 183,1990-07-02,Gender/Gender,M,,1,,PATIENT
# 183,1990-07-02,Race/Race,Non-White,,1,,PATIENT
# 183,1990-09-22,ICD10CM/7P175T0I,,,10,,DIAGNOSIS
# 183,1990-12-07,ICD10CM/3IYNJ8US,,,4,,DIAGNOSIS
# 183,1991-01-22,ICD10CM/GK8MXWHV,,,15,,DIAGNOSIS
# 183,1991-03-14,ICD10CM/2JNTL3UO,,,19,,DIAGNOSIS
# 183,1991-05-17,ICD10CM/8K4AF90P,,,3,,DIAGNOSIS
# 183,1991-06-23,ICD10CM/0X10OYR1,,,5,,DIAGNOSIS
# 183,1991-08-04,ICD10CM/EOR73JR0,,,7,,DIAGNOSIS
# 183,1991-08-29,ICD10CM/6VLKX1ZP,,,11,,DIAGNOSIS
# 183,1991-11-05,ICD10CM/10W461O0,,,18,,DIAGNOSIS
# 183,1992-02-03,ICD10CM/TJCHO61Z,,,9,,DIAGNOSIS
# 183,1992-04-26,CPT/L7IKF3RV,,,0,,PROCEDURES
# 183,1992-05-02,CPT/APLJQQ2B,,,2,,PROCEDURES
# 183,1992-06-05,CPT/DRXEPAB5,,,4,,PROCEDURES
# 183,1992-06-11,Drug/FWFH2WS6,,46,1,mg,MED_ORDER
# 183,1992-07-05,Drug/XL3N6FAL,,44,15,mg,MED_ORDER
# 183,1992-07-31,Drug/ND986RDL,,26,4,mg,MED_ORDER
# 183,1992-10-11,Drug/MJ513BYF,,18,4,mg,MED_ORDER
# 183,1992-10-17,Vitals/VR2FS44V,179,,15,mmHg,LAB_RESULT
# 183,1993-01-02,Vitals/ZAKKNSGY,85,,20,mmHg,LAB_RESULT
# 184,1992-06-15,Birth/Birth,,,1,,PATIENT
# 184,1992-06-15,Gender/Gender,M,,1,,PATIENT
# 184,1992-06-15,Race/Race,Non-White,,1,,PATIENT
# 184,1992-06-18,ICD10CM/SVAIAZWJ,,,2,,DIAGNOSIS
# 184,1992-08-24,ICD10CM/OHVV1TTN,,,12,,DIAGNOSIS
# 184,1992-09-18,ICD10CM/NS0KRSG3,,,17,,DIAGNOSIS
# 184,1992-10-09,ICD10CM/89UX9V1Q,,,3,,DIAGNOSIS
# 184,1992-12-18,ICD10CM/LO9BZMH2,,,7,,DIAGNOSIS
# 184,1993-02-06,CPT/18PSQZ17,,,19,,PROCEDURES
# 184,1993-02-12,CPT/HPQW2WQU,,,0,,PROCEDURES
# 184,1993-04-13,CPT/FTK8E9JR,,,17,,PROCEDURES
# 184,1993-06-02,CPT/HIUVOYLX,,,11,,PROCEDURES
# 184,1993-08-26,CPT/L0GQIV8F,,,17,,PROCEDURES
# 184,1993-11-18,CPT/VOX6XY4P,,,18,,PROCEDURES
# 184,1993-11-25,Drug/PRCGY8E2,,27,0,mg,MED_ORDER
# 184,1994-02-05,Drug/PNO9JZSK,,33,10,mg,MED_ORDER
# 184,1994-02-24,Drug/S23MDTPA,,45,3,mg,MED_ORDER
# 184,1994-06-04,Drug/5UN5C5A8,,15,9,mg,MED_ORDER
# 184,1994-08-26,Drug/B1LGITAH,,22,9,mg,MED_ORDER
# 184,1994-10-13,Drug/024QNDR1,,50,11,mg,MED_ORDER
# 184,1994-12-09,Vitals/E955WTOC,198,,10,mmHg,LAB_RESULT
# 184,1995-02-13,Vitals/MALR9M9X,81,,0,mmHg,LAB_RESULT
# 184,1995-02-17,Vitals/LTG26EJ7,141,,19,mmHg,LAB_RESULT
# 184,1995-04-26,Vitals/M0MOIS0Z,162,,8,mmHg,LAB_RESULT
# 184,1995-05-10,Vitals/M96APUJE,130,,0,mmHg,LAB_RESULT
# 184,1995-06-02,Vitals/MN4TBLOO,159,,18,mmHg,LAB_RESULT
# 184,1995-07-21,Vitals/39T8GXH7,191,,18,mmHg,LAB_RESULT
# 184,1995-10-06,Vitals/QZJ375J6,160,,17,mmHg,LAB_RESULT
# 184,1995-11-29,Vitals/SGR95CO5,139,,20,mmHg,LAB_RESULT
# 185,1990-12-11,Birth/Birth,,,1,,PATIENT
# 185,1990-12-11,Gender/Gender,F,,1,,PATIENT
# 185,1990-12-11,Race/Race,White,,1,,PATIENT
# 185,1991-03-07,ICD10CM/EKB0H9SH,,,11,,DIAGNOSIS
# 185,1991-04-11,ICD10CM/TIRLT8NP,,,10,,DIAGNOSIS
# 185,1991-04-28,ICD10CM/YGLP2GZQ,,,1,,DIAGNOSIS
# 185,1991-07-25,CPT/WU0PRBCW,,,1,,PROCEDURES
# 185,1991-10-12,CPT/IVAM0VKD,,,0,,PROCEDURES
# 185,1991-11-29,CPT/H9NN80E4,,,6,,PROCEDURES
# 185,1991-12-20,CPT/DJMTP7NH,,,18,,PROCEDURES
# 185,1992-03-10,CPT/CJ73N5O6,,,20,,PROCEDURES
# 185,1992-06-13,CPT/WKAFLK96,,,18,,PROCEDURES
# 185,1992-08-01,CPT/XQGB0HED,,,14,,PROCEDURES
# 185,1992-08-20,CPT/X0TF0Q5L,,,7,,PROCEDURES
# 185,1992-09-19,CPT/RU3PZDOS,,,10,,PROCEDURES
# 185,1992-11-20,Drug/9APQJ6P6,,40,15,mg,MED_ORDER
# 185,1992-11-28,Drug/QMAIX6Y4,,19,6,mg,MED_ORDER
# 185,1993-01-11,Drug/6ACWIJBW,,14,16,mg,MED_ORDER
# 185,1993-04-20,Drug/ZUEAHVWR,,18,6,mg,MED_ORDER
# 185,1993-07-07,Drug/S98HXCUR,,29,10,mg,MED_ORDER
# 185,1993-09-16,Drug/GQQPZTGL,,19,8,mg,MED_ORDER
# 185,1993-11-28,Drug/RY797VQ3,,33,5,mg,MED_ORDER
# 185,1993-12-12,Vitals/KGSK0FVO,102,,2,mmHg,LAB_RESULT
# 185,1994-02-04,Vitals/YN4O60JU,109,,17,mmHg,LAB_RESULT
# 185,1994-05-11,Vitals/TTS95SVE,149,,13,mmHg,LAB_RESULT
# 185,1994-07-03,Vitals/LAQM7E93,143,,7,mmHg,LAB_RESULT
# 185,1994-08-14,Vitals/T8OHT3DC,185,,19,mmHg,LAB_RESULT
# 185,1994-10-26,Vitals/XQO6J9GP,145,,14,mmHg,LAB_RESULT
# 185,1995-01-15,Vitals/I6UQ16U7,129,,11,mmHg,LAB_RESULT
# 185,1995-02-18,Vitals/DYQBLZ5V,139,,20,mmHg,LAB_RESULT
# 185,1995-03-29,Vitals/0NNZ1VZT,139,,6,mmHg,LAB_RESULT
# 186,1991-07-04,Birth/Birth,,,1,,PATIENT
# 186,1991-07-04,Gender/Gender,F,,1,,PATIENT
# 186,1991-07-04,Race/Race,White,,1,,PATIENT
# 186,1991-10-07,ICD10CM/J3YEF4U4,,,9,,DIAGNOSIS
# 186,1992-01-11,ICD10CM/9PJC0HFN,,,12,,DIAGNOSIS
# 186,1992-03-18,ICD10CM/T36WXGA6,,,7,,DIAGNOSIS
# 186,1992-04-21,ICD10CM/4ZL5W0HT,,,15,,DIAGNOSIS
# 186,1992-07-01,ICD10CM/IIEGDJYB,,,18,,DIAGNOSIS
# 186,1992-07-22,ICD10CM/RZRFKF4U,,,4,,DIAGNOSIS
# 186,1992-08-14,ICD10CM/KZYTHTXP,,,4,,DIAGNOSIS
# 186,1992-08-31,ICD10CM/35A1ZW3H,,,2,,DIAGNOSIS
# 186,1992-09-28,ICD10CM/LD5C5H3G,,,1,,DIAGNOSIS
# 186,1992-11-07,CPT/IR23NF28,,,20,,PROCEDURES
# 186,1992-11-21,CPT/7ZPWN78A,,,14,,PROCEDURES
# 186,1993-02-16,CPT/NFMJ9MEA,,,4,,PROCEDURES
# 186,1993-02-23,CPT/P0MYV645,,,19,,PROCEDURES
# 186,1993-04-22,CPT/RZO5IPCQ,,,0,,PROCEDURES
# 186,1993-07-04,CPT/6X4OESDZ,,,7,,PROCEDURES
# 186,1993-09-08,CPT/ANHK19DI,,,9,,PROCEDURES
# 186,1993-09-14,CPT/P9DIQXX4,,,6,,PROCEDURES
# 186,1993-10-18,CPT/42SEXBGM,,,6,,PROCEDURES
# 186,1993-11-06,CPT/Q21P5TD2,,,6,,PROCEDURES
# 186,1993-11-27,Drug/MM3EMV9G,,12,5,mg,MED_ORDER
# 186,1994-02-25,Drug/0OXZOJ96,,19,9,mg,MED_ORDER
# 186,1994-04-02,Drug/HFPS0R33,,19,5,mg,MED_ORDER
# 186,1994-06-20,Drug/ZEO7320W,,50,12,mg,MED_ORDER
# 186,1994-09-20,Drug/MLA11ESW,,10,4,mg,MED_ORDER
# 186,1994-12-15,Drug/ZKOSU1QA,,22,14,mg,MED_ORDER
# 186,1995-01-11,Drug/YZLUR0F6,,14,1,mg,MED_ORDER
# 186,1995-03-19,Vitals/UKSL3APU,157,,13,mmHg,LAB_RESULT
# 186,1995-04-25,Vitals/V4R29LRG,141,,1,mmHg,LAB_RESULT
# 186,1995-07-19,Vitals/BWNEONXF,98,,17,mmHg,LAB_RESULT
# 186,1995-10-15,Vitals/IU0U335Q,172,,12,mmHg,LAB_RESULT
# 186,1995-11-10,Vitals/8Q3PWSPR,180,,20,mmHg,LAB_RESULT
# 186,1996-01-05,Vitals/H0MVQN9T,98,,4,mmHg,LAB_RESULT
# 186,1996-03-06,Vitals/3MLVPH9Q,100,,20,mmHg,LAB_RESULT
# 186,1996-06-13,Vitals/FVTD7K3R,122,,14,mmHg,LAB_RESULT
# 187,1992-03-09,Birth/Birth,,,1,,PATIENT
# 187,1992-03-09,Gender/Gender,F,,1,,PATIENT
# 187,1992-03-09,Race/Race,White,,1,,PATIENT
# 187,1992-06-16,ICD10CM/DHC4F3ZX,,,17,,DIAGNOSIS
# 187,1992-07-17,ICD10CM/9JM5F264,,,9,,DIAGNOSIS
# 187,1992-08-19,ICD10CM/5UY23N5K,,,9,,DIAGNOSIS
# 187,1992-11-15,ICD10CM/B630WORN,,,1,,DIAGNOSIS
# 187,1993-02-10,ICD10CM/S3LLT66M,,,11,,DIAGNOSIS
# 187,1993-05-12,ICD10CM/NRYSEFH9,,,9,,DIAGNOSIS
# 187,1993-07-04,CPT/AWGYY0L7,,,2,,PROCEDURES
# 187,1993-09-11,CPT/MZ9Z3Y2D,,,10,,PROCEDURES
# 187,1993-10-10,CPT/S1JOTW6L,,,0,,PROCEDURES
# 187,1993-11-30,CPT/ICS9BBQG,,,4,,PROCEDURES
# 187,1994-02-14,CPT/MI95KT24,,,11,,PROCEDURES
# 187,1994-02-15,CPT/2DHFXI4K,,,6,,PROCEDURES
# 187,1994-03-21,CPT/1EBUJX21,,,9,,PROCEDURES
# 187,1994-05-22,CPT/PO0OUIW6,,,16,,PROCEDURES
# 187,1994-06-14,CPT/6DI99V4H,,,12,,PROCEDURES
# 187,1994-07-08,Drug/NMGVRHUP,,20,17,mg,MED_ORDER
# 187,1994-09-29,Drug/LAT8VSPY,,19,8,mg,MED_ORDER
# 187,1994-10-30,Vitals/442L5K8Y,87,,20,mmHg,LAB_RESULT
# 187,1994-12-01,Vitals/KW18U2RF,90,,14,mmHg,LAB_RESULT
# 187,1994-12-28,Vitals/4D7RVDFE,117,,12,mmHg,LAB_RESULT
# 188,1992-09-24,Birth/Birth,,,1,,PATIENT
# 188,1992-09-24,Gender/Gender,F,,1,,PATIENT
# 188,1992-09-24,Race/Race,White,,1,,PATIENT
# 188,1992-11-01,ICD10CM/0CMOLQ60,,,15,,DIAGNOSIS
# 188,1993-02-06,ICD10CM/GO3P9IAS,,,14,,DIAGNOSIS
# 188,1993-03-08,ICD10CM/2VPUBOTE,,,13,,DIAGNOSIS
# 188,1993-04-02,ICD10CM/5INCRVMA,,,17,,DIAGNOSIS
# 188,1993-06-07,ICD10CM/FZY78ME1,,,0,,DIAGNOSIS
# 188,1993-07-15,ICD10CM/3QW9Z23L,,,8,,DIAGNOSIS
# 188,1993-10-17,ICD10CM/UMR73H2T,,,4,,DIAGNOSIS
# 188,1993-12-13,CPT/RR63ET8Y,,,12,,PROCEDURES
# 188,1994-01-15,CPT/6YEE3QZD,,,20,,PROCEDURES
# 188,1994-03-08,CPT/MS1JFNVA,,,10,,PROCEDURES
# 188,1994-06-01,CPT/O2X7A2A4,,,7,,PROCEDURES
# 188,1994-07-28,CPT/44D9ZJDD,,,0,,PROCEDURES
# 188,1994-09-16,CPT/JSM8P0IV,,,20,,PROCEDURES
# 188,1994-12-02,CPT/RI61BKUV,,,19,,PROCEDURES
# 188,1995-01-20,CPT/DFP3T91R,,,3,,PROCEDURES
# 188,1995-02-24,CPT/RVT7WY4I,,,11,,PROCEDURES
# 188,1995-03-07,Drug/INCTTRNL,,46,20,mg,MED_ORDER
# 188,1995-05-26,Drug/YQ7NLBIV,,49,18,mg,MED_ORDER
# 188,1995-06-30,Drug/WP3S65SB,,50,11,mg,MED_ORDER
# 188,1995-08-06,Drug/XWAT9ABT,,17,0,mg,MED_ORDER
# 188,1995-10-11,Drug/5RAM2NX2,,19,2,mg,MED_ORDER
# 188,1995-10-14,Drug/CSDP35NC,,29,10,mg,MED_ORDER
# 188,1995-11-08,Vitals/RXLGOQLA,182,,14,mmHg,LAB_RESULT
# 188,1996-01-15,Vitals/5ZGQMMN8,134,,0,mmHg,LAB_RESULT
# 188,1996-04-14,Vitals/E0QPXXNR,139,,20,mmHg,LAB_RESULT
# 188,1996-06-16,Vitals/E20QP4K7,183,,9,mmHg,LAB_RESULT
# 189,1990-09-05,Birth/Birth,,,1,,PATIENT
# 189,1990-09-05,Gender/Gender,F,,1,,PATIENT
# 189,1990-09-05,Race/Race,White,,1,,PATIENT
# 189,1990-10-15,ICD10CM/QMX5DVRT,,,6,,DIAGNOSIS
# 189,1991-01-18,ICD10CM/8FKKOUP0,,,6,,DIAGNOSIS
# 189,1991-03-12,ICD10CM/QDGLRG89,,,14,,DIAGNOSIS
# 189,1991-03-28,ICD10CM/GMU5CQOS,,,8,,DIAGNOSIS
# 189,1991-04-19,ICD10CM/GJKO43K7,,,9,,DIAGNOSIS
# 189,1991-06-04,CPT/U7KFJH6G,,,3,,PROCEDURES
# 189,1991-08-12,CPT/0X4THJPP,,,19,,PROCEDURES
# 189,1991-10-27,Drug/5XA29GTT,,11,7,mg,MED_ORDER
# 189,1991-12-15,Drug/3PP27DOA,,15,3,mg,MED_ORDER
# 189,1991-12-19,Drug/VJ2ZSHI3,,33,16,mg,MED_ORDER
# 189,1992-01-07,Vitals/SZSFWPO7,133,,7,mmHg,LAB_RESULT
# 189,1992-01-31,Vitals/4WXCU0H1,109,,4,mmHg,LAB_RESULT
# 189,1992-02-29,Vitals/ROW3G1YC,90,,3,mmHg,LAB_RESULT
# 189,1992-05-17,Vitals/0Q8243SV,160,,3,mmHg,LAB_RESULT
# 189,1992-07-02,Vitals/115QOYTY,197,,20,mmHg,LAB_RESULT
# 190,1990-09-23,Birth/Birth,,,1,,PATIENT
# 190,1990-09-23,Gender/Gender,M,,1,,PATIENT
# 190,1990-09-23,Race/Race,Non-White,,1,,PATIENT
# 190,1990-10-08,ICD10CM/ZEH2CZZZ,,,10,,DIAGNOSIS
# 190,1990-11-27,ICD10CM/M1ECTHS8,,,19,,DIAGNOSIS
# 190,1990-12-09,ICD10CM/SYOUU7HE,,,20,,DIAGNOSIS
# 190,1991-01-30,CPT/7HWRFO2Z,,,15,,PROCEDURES
# 190,1991-02-07,CPT/31Z0FDOR,,,10,,PROCEDURES
# 190,1991-03-27,CPT/XF0WLZQF,,,4,,PROCEDURES
# 190,1991-05-01,CPT/H9PUFIQD,,,14,,PROCEDURES
# 190,1991-06-28,CPT/SO1YKRTU,,,6,,PROCEDURES
# 190,1991-10-06,CPT/B6M5UPD7,,,10,,PROCEDURES
# 190,1991-10-24,Drug/5L4YOIE1,,45,8,mg,MED_ORDER
# 190,1991-12-01,Drug/1ZJ03XSQ,,17,17,mg,MED_ORDER
# 190,1992-01-26,Drug/U5CNJDTQ,,23,16,mg,MED_ORDER
# 190,1992-03-09,Drug/YSH6UKFV,,15,15,mg,MED_ORDER
# 190,1992-04-16,Drug/0DQ6O7GK,,33,14,mg,MED_ORDER
# 190,1992-05-14,Drug/8JJZFB3R,,42,7,mg,MED_ORDER
# 190,1992-07-15,Vitals/B6P1I0UC,90,,17,mmHg,LAB_RESULT
# 190,1992-08-26,Vitals/L2EBLEO9,156,,5,mmHg,LAB_RESULT
# 190,1992-09-06,Vitals/T6T34EFK,128,,1,mmHg,LAB_RESULT
# 190,1992-10-07,Vitals/DPAB1AT8,95,,18,mmHg,LAB_RESULT
# 190,1992-10-08,Vitals/I1UJ4O2O,122,,16,mmHg,LAB_RESULT
# 190,1993-01-10,Vitals/Z8Y4F52W,93,,8,mmHg,LAB_RESULT
# 191,1991-08-26,Birth/Birth,,,1,,PATIENT
# 191,1991-08-26,Gender/Gender,M,,1,,PATIENT
# 191,1991-08-26,Race/Race,Non-White,,1,,PATIENT
# 191,1991-08-31,ICD10CM/LT3BZIJK,,,0,,DIAGNOSIS
# 191,1991-11-12,ICD10CM/J8GCEQ3O,,,8,,DIAGNOSIS
# 191,1992-01-11,ICD10CM/9BVIFL38,,,14,,DIAGNOSIS
# 191,1992-04-06,ICD10CM/T8N6GIGQ,,,16,,DIAGNOSIS
# 191,1992-07-06,ICD10CM/VQ900LIR,,,0,,DIAGNOSIS
# 191,1992-07-19,ICD10CM/CSYQF7YY,,,20,,DIAGNOSIS
# 191,1992-10-23,ICD10CM/LOMIF8ND,,,4,,DIAGNOSIS
# 191,1992-12-21,ICD10CM/D0AQQK9B,,,9,,DIAGNOSIS
# 191,1993-01-03,ICD10CM/6LLL7J7K,,,9,,DIAGNOSIS
# 191,1993-02-07,ICD10CM/FRI7HTSA,,,1,,DIAGNOSIS
# 191,1993-02-20,CPT/NVMRI17Z,,,5,,PROCEDURES
# 191,1993-03-11,CPT/N1WE45N5,,,11,,PROCEDURES
# 191,1993-04-13,CPT/P28CF2DU,,,3,,PROCEDURES
# 191,1993-05-24,CPT/KQ4EZWFE,,,9,,PROCEDURES
# 191,1993-05-24,CPT/BVZXXPUX,,,6,,PROCEDURES
# 191,1993-06-29,CPT/LHTMODI5,,,3,,PROCEDURES
# 191,1993-09-16,CPT/L2G1KV4Z,,,17,,PROCEDURES
# 191,1993-10-27,CPT/LMHTY3S8,,,5,,PROCEDURES
# 191,1994-01-11,CPT/UJICQONX,,,12,,PROCEDURES
# 191,1994-04-18,CPT/9KUJA0OY,,,11,,PROCEDURES
# 191,1994-04-25,Drug/INO8B6TQ,,15,20,mg,MED_ORDER
# 191,1994-04-27,Drug/XJ4OVVPL,,15,12,mg,MED_ORDER
# 191,1994-05-26,Drug/JHD9TQXR,,24,11,mg,MED_ORDER
# 191,1994-06-05,Drug/M3IT6N64,,25,0,mg,MED_ORDER
# 191,1994-08-11,Drug/WG17GJRG,,44,9,mg,MED_ORDER
# 191,1994-09-03,Drug/UQV3E6OK,,41,16,mg,MED_ORDER
# 191,1994-10-22,Drug/T786JTYH,,20,5,mg,MED_ORDER
# 191,1995-01-25,Drug/R1Y336VW,,20,8,mg,MED_ORDER
# 191,1995-04-18,Vitals/FDGGK5YW,191,,4,mmHg,LAB_RESULT
# 191,1995-06-03,Vitals/KPC9XWKJ,172,,0,mmHg,LAB_RESULT
# 191,1995-08-01,Vitals/IUYSY3WU,180,,17,mmHg,LAB_RESULT
# 191,1995-10-09,Vitals/CSMWCBGR,125,,8,mmHg,LAB_RESULT
# 191,1995-10-19,Vitals/02D3C7GA,170,,0,mmHg,LAB_RESULT
# 191,1995-11-04,Vitals/001DTAV1,80,,4,mmHg,LAB_RESULT
# 191,1995-12-13,Vitals/2NF3BXNR,159,,5,mmHg,LAB_RESULT
# 192,1990-05-02,Birth/Birth,,,1,,PATIENT
# 192,1990-05-02,Gender/Gender,M,,1,,PATIENT
# 192,1990-05-02,Race/Race,Non-White,,1,,PATIENT
# 192,1990-07-11,ICD10CM/18ZMT55S,,,13,,DIAGNOSIS
# 192,1990-08-05,ICD10CM/IT5QWVI0,,,2,,DIAGNOSIS
# 192,1990-08-18,ICD10CM/T0PJUEJX,,,6,,DIAGNOSIS
# 192,1990-10-16,ICD10CM/3HEOW35L,,,0,,DIAGNOSIS
# 192,1990-12-05,ICD10CM/CA5QHLPQ,,,11,,DIAGNOSIS
# 192,1991-02-25,ICD10CM/XB7IPXVH,,,9,,DIAGNOSIS
# 192,1991-03-27,ICD10CM/FBCYWB6V,,,20,,DIAGNOSIS
# 192,1991-05-01,ICD10CM/3OJVK9M4,,,16,,DIAGNOSIS
# 192,1991-05-11,ICD10CM/ICSMDD4G,,,16,,DIAGNOSIS
# 192,1991-07-06,CPT/5XU9I514,,,6,,PROCEDURES
# 192,1991-10-11,CPT/ZXW7K4VJ,,,2,,PROCEDURES
# 192,1992-01-12,CPT/VTPTMGJV,,,1,,PROCEDURES
# 192,1992-03-13,Drug/3ZTH70WV,,40,12,mg,MED_ORDER
# 192,1992-04-01,Drug/RL2DRXY5,,32,11,mg,MED_ORDER
# 192,1992-06-06,Drug/P6L204GC,,14,10,mg,MED_ORDER
# 192,1992-08-25,Drug/HPKEYRMD,,20,11,mg,MED_ORDER
# 192,1992-09-02,Drug/NBJIU626,,11,10,mg,MED_ORDER
# 192,1992-09-13,Drug/XMRGOCVS,,44,14,mg,MED_ORDER
# 192,1992-11-29,Vitals/E1JFGANC,93,,8,mmHg,LAB_RESULT
# 192,1993-01-19,Vitals/NV47G7K1,163,,6,mmHg,LAB_RESULT
# 192,1993-03-30,Vitals/B1MGUDIA,133,,8,mmHg,LAB_RESULT
# 192,1993-05-01,Vitals/T9OSEKB4,95,,17,mmHg,LAB_RESULT
# 193,1990-11-13,Birth/Birth,,,1,,PATIENT
# 193,1990-11-13,Gender/Gender,M,,1,,PATIENT
# 193,1990-11-13,Race/Race,Non-White,,1,,PATIENT
# 193,1990-11-16,ICD10CM/4WUMD104,,,2,,DIAGNOSIS
# 193,1990-11-29,ICD10CM/FXQXJ1FU,,,16,,DIAGNOSIS
# 193,1991-02-06,ICD10CM/IF1FRCS2,,,1,,DIAGNOSIS
# 193,1991-04-04,ICD10CM/QQ3MCRUN,,,18,,DIAGNOSIS
# 193,1991-07-13,ICD10CM/FUDPM0CL,,,1,,DIAGNOSIS
# 193,1991-10-15,ICD10CM/7PP5CQEB,,,15,,DIAGNOSIS
# 193,1991-10-23,ICD10CM/JP1IRAM7,,,16,,DIAGNOSIS
# 193,1991-12-03,ICD10CM/B41DIDCK,,,9,,DIAGNOSIS
# 193,1992-02-13,ICD10CM/1V8YNKTW,,,7,,DIAGNOSIS
# 193,1992-04-10,ICD10CM/PDCPO222,,,12,,DIAGNOSIS
# 193,1992-07-10,CPT/Q76BARQ8,,,12,,PROCEDURES
# 193,1992-07-23,CPT/DS5FMCWG,,,3,,PROCEDURES
# 193,1992-10-27,CPT/JAAVNLZC,,,4,,PROCEDURES
# 193,1993-01-20,CPT/IG2EUY1D,,,16,,PROCEDURES
# 193,1993-03-09,CPT/SCNGZHDI,,,16,,PROCEDURES
# 193,1993-04-07,CPT/CQA35NOS,,,7,,PROCEDURES
# 193,1993-05-01,CPT/0T6QFGQC,,,12,,PROCEDURES
# 193,1993-07-03,CPT/WYUWMQ3G,,,2,,PROCEDURES
# 193,1993-08-16,CPT/MMHWBGJU,,,9,,PROCEDURES
# 193,1993-08-23,CPT/O1JCO6JU,,,4,,PROCEDURES
# 193,1993-09-26,Drug/Z20FSJFF,,29,18,mg,MED_ORDER
# 193,1993-12-02,Vitals/RPX98E04,163,,20,mmHg,LAB_RESULT
# 193,1994-03-10,Vitals/8PUP4YVT,134,,7,mmHg,LAB_RESULT
# 194,1991-12-04,Birth/Birth,,,1,,PATIENT
# 194,1991-12-04,Gender/Gender,M,,1,,PATIENT
# 194,1991-12-04,Race/Race,Non-White,,1,,PATIENT
# 194,1992-03-01,ICD10CM/QKS2499K,,,1,,DIAGNOSIS
# 194,1992-05-31,ICD10CM/V53FIYMF,,,17,,DIAGNOSIS
# 194,1992-08-06,ICD10CM/ZCRUI27K,,,8,,DIAGNOSIS
# 194,1992-10-18,ICD10CM/Z8PL6B8P,,,12,,DIAGNOSIS
# 194,1992-11-29,ICD10CM/U1AD8VDE,,,0,,DIAGNOSIS
# 194,1992-12-01,ICD10CM/DOA2KIZT,,,19,,DIAGNOSIS
# 194,1993-02-11,CPT/2ZW7BAJU,,,1,,PROCEDURES
# 194,1993-04-28,Drug/6A3VTIV6,,12,15,mg,MED_ORDER

# %% [markdown]
# # Additional notes
# Ordering of rows for each patient, or patient rows being split across files doesn't matter. Everything will be resorted and joined as part of the ETL process.
#
# Other atypical datatypes, such as flowsheets can be added as needed, with either string or numeric values as whatever is more natural.
#
# # 4. Convert the directory to an extract
# We now convert the dataset we created above to an extract using the function [etl_simple_femr](https://github.com/som-shahlab/femr/blob/main/src/femr/etl_pipelines/simple.py#L66) from the femr repo
#
# The output extract is a femr [PatientDatabase](https://github.com/som-shahlab/femr/blob/Miking98-patch-1/tutorials/0_How%20FEMR%20Works%20%2B%20Toy%20Example.ipynb) that can be directly used by the femr pipeline

# %%
# Create directories for storing the extract and extract log
LOG_DIR = os.path.join(TARGET_DIR, "logs")
EXTRACT_DIR = os.path.join(TARGET_DIR, "extract")

import femr
import femr.etl_pipelines.simple
os.system(f"etl_simple_femr {INPUT_DIR} {EXTRACT_DIR} {LOG_DIR} --num_threads 2")
# Out:
# 2023-04-19 16:23:04,449 [MainThread  ] [INFO ]  Extracting from OMOP with arguments Namespace(simple_source='trash/simple_femr/simple_input', target_location='/local-scratch/nigam/projects/yizhex/trash/simple_femr/extract', temp_location='/local-scratch/nigam/projects/yizhex/trash/simple_femr/logs', num_threads=2)
# 2023-04-19 16:23:04,450 [MainThread  ] [INFO ]  Converting to events
# 2023-04-19 16:23:04,536 [MainThread  ] [INFO ]  Converting to patients
# 2023-04-19 16:23:04,575 [MainThread  ] [INFO ]  Converting to extract
# Done with main 2023-04-19T16:23:04.623173171+00:00
# Done with meta 2023-04-19T16:23:04.623279935+00:00
# Converting to extract 2023-04-19 16:23:04.575945
# 0

# %% [markdown]
# # 5. Open and view the data
# We now open and take a look at the femr extract we generated in the last step using the function [PatientDatabase](https://github.com/som-shahlab/femr/blob/main/src/femr/extension/datasets.pyi#L24) from the femr repo

# %%
import femr.datasets

database = femr.datasets.PatientDatabase(EXTRACT_DIR)

# Number of patients
print("Num patients", len(database))

# Print out the first patient
patient = database[0]
print(patient)

# Note that the patient ids get remapped, you can unmap with the database
original_id = database.get_original_patient_id(0)
print("Oiringla id for patient 0", original_id)

# Also note that concepts have been mapped to integers
print("What code 3 means", database.get_code_dictionary()[3])  # Returns what code=3 means in the database

# You can pull things like dosage by looking at the event
for event in patient.events:
    print(event, event.dosage)
# Out:
# Num patients 100
# Patient(patient_id=0, events=(Event(start=1990-11-04 00:00:00, code=1, value=Non-White, dosage=, visit_ids=1, lab_units=, clarity_source=PATIENT), Event(start=1990-11-04 00:00:00, code=0, dosage=, visit_ids=1, lab_units=, clarity_source=PATIENT), Event(start=1990-11-04 00:00:00, code=2, value=M, dosage=, visit_ids=1, lab_units=, clarity_source=PATIENT), Event(start=1990-12-26 00:00:00, code=202, dosage=, visit_ids=20, lab_units=, clarity_source=DIAGNOSIS), Event(start=1990-12-31 00:00:00, code=1130, dosage=, visit_ids=17, lab_units=, clarity_source=DIAGNOSIS), Event(start=1991-01-31 00:00:00, code=1643, dosage=, visit_ids=1, lab_units=, clarity_source=DIAGNOSIS), Event(start=1991-04-22 00:00:00, code=728, dosage=, visit_ids=13, lab_units=, clarity_source=DIAGNOSIS), Event(start=1991-05-11 00:00:00, code=710, dosage=, visit_ids=11, lab_units=, clarity_source=DIAGNOSIS), Event(start=1991-06-30 00:00:00, code=20, dosage=, visit_ids=20, lab_units=, clarity_source=DIAGNOSIS), Event(start=1991-09-30 00:00:00, code=1404, dosage=, visit_ids=7, lab_units=, clarity_source=DIAGNOSIS), Event(start=1991-12-22 00:00:00, code=625, dosage=, visit_ids=5, lab_units=, clarity_source=DIAGNOSIS), Event(start=1992-02-24 00:00:00, code=597, dosage=, visit_ids=3, lab_units=, clarity_source=DIAGNOSIS), Event(start=1992-03-19 00:00:00, code=635, dosage=, visit_ids=16, lab_units=, clarity_source=PROCEDURES), Event(start=1992-06-14 00:00:00, code=2195, dosage=, visit_ids=3, lab_units=, clarity_source=PROCEDURES), Event(start=1992-07-20 00:00:00, code=2126, dosage=, visit_ids=18, lab_units=, clarity_source=PROCEDURES), Event(start=1992-10-05 00:00:00, code=1205, dosage=, visit_ids=18, lab_units=, clarity_source=PROCEDURES), Event(start=1992-10-13 00:00:00, code=705, dosage=, visit_ids=17, lab_units=, clarity_source=PROCEDURES), Event(start=1992-12-27 00:00:00, code=2191, dosage=, visit_ids=10, lab_units=, clarity_source=PROCEDURES), Event(start=1993-01-19 00:00:00, code=2205, dosage=, visit_ids=10, lab_units=, clarity_source=PROCEDURES), Event(start=1993-03-01 00:00:00, code=197, dosage=, visit_ids=8, lab_units=, clarity_source=PROCEDURES), Event(start=1993-03-18 00:00:00, code=767, dosage=, visit_ids=14, lab_units=, clarity_source=PROCEDURES), Event(start=1993-04-07 00:00:00, code=1231, dosage=21, visit_ids=6, lab_units=mg, clarity_source=MED_ORDER), Event(start=1993-06-04 00:00:00, code=328, dosage=41, visit_ids=18, lab_units=mg, clarity_source=MED_ORDER), Event(start=1993-06-28 00:00:00, code=1622, value=168.0, dosage=, visit_ids=20, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1993-09-13 00:00:00, code=379, value=98.0, dosage=, visit_ids=18, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1993-10-09 00:00:00, code=1742, value=150.0, dosage=, visit_ids=14, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1993-11-25 00:00:00, code=1553, value=188.0, dosage=, visit_ids=6, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1994-02-27 00:00:00, code=297, value=171.0, dosage=, visit_ids=6, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1994-04-21 00:00:00, code=1874, value=141.0, dosage=, visit_ids=2, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1994-05-18 00:00:00, code=1962, value=188.0, dosage=, visit_ids=1, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1994-06-27 00:00:00, code=416, value=168.0, dosage=, visit_ids=9, lab_units=mmHg, clarity_source=LAB_RESULT), Event(start=1994-06-30 00:00:00, code=1070, value=142.0, dosage=, visit_ids=19, lab_units=mmHg, clarity_source=LAB_RESULT)))
# Oiringla id for patient 0 101
# What code 3 means CPT/QB1ZKZNM
# Event(start=1990-11-04 00:00:00, code=1, value=Non-White, dosage=, visit_ids=1, lab_units=, clarity_source=PATIENT)
# Event(start=1990-11-04 00:00:00, code=0, dosage=, visit_ids=1, lab_units=, clarity_source=PATIENT)
# Event(start=1990-11-04 00:00:00, code=2, value=M, dosage=, visit_ids=1, lab_units=, clarity_source=PATIENT)
# Event(start=1990-12-26 00:00:00, code=202, dosage=, visit_ids=20, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1990-12-31 00:00:00, code=1130, dosage=, visit_ids=17, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1991-01-31 00:00:00, code=1643, dosage=, visit_ids=1, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1991-04-22 00:00:00, code=728, dosage=, visit_ids=13, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1991-05-11 00:00:00, code=710, dosage=, visit_ids=11, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1991-06-30 00:00:00, code=20, dosage=, visit_ids=20, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1991-09-30 00:00:00, code=1404, dosage=, visit_ids=7, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1991-12-22 00:00:00, code=625, dosage=, visit_ids=5, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1992-02-24 00:00:00, code=597, dosage=, visit_ids=3, lab_units=, clarity_source=DIAGNOSIS)
# Event(start=1992-03-19 00:00:00, code=635, dosage=, visit_ids=16, lab_units=, clarity_source=PROCEDURES)
# Event(start=1992-06-14 00:00:00, code=2195, dosage=, visit_ids=3, lab_units=, clarity_source=PROCEDURES)
# Event(start=1992-07-20 00:00:00, code=2126, dosage=, visit_ids=18, lab_units=, clarity_source=PROCEDURES)
# Event(start=1992-10-05 00:00:00, code=1205, dosage=, visit_ids=18, lab_units=, clarity_source=PROCEDURES)
# Event(start=1992-10-13 00:00:00, code=705, dosage=, visit_ids=17, lab_units=, clarity_source=PROCEDURES)
# Event(start=1992-12-27 00:00:00, code=2191, dosage=, visit_ids=10, lab_units=, clarity_source=PROCEDURES)
# Event(start=1993-01-19 00:00:00, code=2205, dosage=, visit_ids=10, lab_units=, clarity_source=PROCEDURES)
# Event(start=1993-03-01 00:00:00, code=197, dosage=, visit_ids=8, lab_units=, clarity_source=PROCEDURES)
# Event(start=1993-03-18 00:00:00, code=767, dosage=, visit_ids=14, lab_units=, clarity_source=PROCEDURES)
# Event(start=1993-04-07 00:00:00, code=1231, dosage=21, visit_ids=6, lab_units=mg, clarity_source=MED_ORDER) 21
# Event(start=1993-06-04 00:00:00, code=328, dosage=41, visit_ids=18, lab_units=mg, clarity_source=MED_ORDER) 41
# Event(start=1993-06-28 00:00:00, code=1622, value=168.0, dosage=, visit_ids=20, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1993-09-13 00:00:00, code=379, value=98.0, dosage=, visit_ids=18, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1993-10-09 00:00:00, code=1742, value=150.0, dosage=, visit_ids=14, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1993-11-25 00:00:00, code=1553, value=188.0, dosage=, visit_ids=6, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1994-02-27 00:00:00, code=297, value=171.0, dosage=, visit_ids=6, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1994-04-21 00:00:00, code=1874, value=141.0, dosage=, visit_ids=2, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1994-05-18 00:00:00, code=1962, value=188.0, dosage=, visit_ids=1, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1994-06-27 00:00:00, code=416, value=168.0, dosage=, visit_ids=9, lab_units=mmHg, clarity_source=LAB_RESULT)
# Event(start=1994-06-30 00:00:00, code=1070, value=142.0, dosage=, visit_ids=19, lab_units=mmHg, clarity_source=LAB_RESULT)
